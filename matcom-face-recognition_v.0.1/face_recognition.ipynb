# %% [markdown]
# # Imports

# %%
#! pip install -r requirements.txt

# %%
import os
import cv2
import random
import numpy as np
import uuid
import matplotlib.pyplot as plt
import datetime
import tarfile
import builtins

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Layer, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.metrics import Precision, Recall
# Out:
# 2024-09-27 08:01:03.375850: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-27 08:01:03.449298: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-27 08:01:03.527643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-27 08:01:03.595394: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-27 08:01:03.612930: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-27 08:01:03.727384: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-27 08:01:04.624306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Flags

# %%
collect_images_flag = False
train_flag = True
save_flag = True

# %% [markdown]
# # Directory Configs

# %%
project_path = os.path.curdir

data_dir = os.path.join(project_path, 'data')
os.makedirs(data_dir, exist_ok=True)

dataset_dir = os.path.join(project_path, 'dataset')
os.makedirs(dataset_dir, exist_ok=True)

checkpoint_dir = os.path.join(project_path,'checkpoints')
os.makedirs(checkpoint_dir, exist_ok=True)

save_model_dir = os.path.join(project_path, 'save_model')
os.makedirs(save_model_dir, exist_ok=True)

db_dir = os.path.join(project_path, 'db')
os.makedirs(save_model_dir, exist_ok=True)

lfw_dir = os.path.join(dataset_dir, 'lfw')

# %% [markdown]
# # Dataset download

# %%
if not os.path.exists(os.path.join(dataset_dir,'lfw.tgz')):
    # !wget http://vis-www.cs.umass.edu/lfw/lfw.tgz -P {dataset_dir}
else:
    print('The file lfw.tgz is already downloaded.')
# Out:
# The file lfw.tgz is already downloaded.

# %% [markdown]
# # Checking and Extracting

# %%
# Verificar si el directorio "data" ya contiene archivos
if os.path.exists(lfw_dir) and len(os.listdir(lfw_dir)) > 0:
    print(f'The "lfw_dir" directory already contains {len(os.listdir(lfw_dir))} files:')
else:
    # Si el directorio "lfw_dir" está vacío, descomprimir el archivo lfw.tgz en una carpeta "lwf"
    lfw_tgz_path = os.path.join(dataset_dir, 'lfw.tgz')
    
    if os.path.exists(lfw_tgz_path):
    # Descomprimir el archivo lfw.tgz en el directorio lwf dentro de "dataset"
        with tarfile.open(lfw_tgz_path, 'r:gz') as tar:
            tar.extractall(path=dataset_dir)
            print('File extracted in the "lwf" directory inside "dataset".')
    else:
        print(f"File {lfw_tgz_path} not found.")
# Out:
# The "lfw_dir" directory already contains 5749 files:

# %%
import os
import shutil

# Verificar si el directorio de destino está vacío
if not os.listdir(data_dir):
    # Iterar sobre las carpetas en el directorio de origen
    for folder_name in os.listdir(lfw_dir):
        folder_path = os.path.join(lfw_dir, folder_name)
        
        # Verificar si es una carpeta
        if os.path.isdir(folder_path):
            # Contar las imágenes dentro de la carpeta
            num_images = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
            
            # Si la carpeta tiene más de 5 imágenes, copiarla al directorio de destino
            if num_images > 5:
                dest_folder_path = os.path.join(data_dir, folder_name)
                shutil.copytree(folder_path, dest_folder_path)
                # print(f"Copiada la carpeta: {folder_name} con {num_images} imágenes.")
                
else:
    print(f"El directorio 'data' no está vacío {len(os.listdir(data_dir))} files:').")
# Out:
# El directorio 'data' no está vacío 311 files:').

# %% [markdown]
# # Collect Images

# %%
import cv2
import os
import uuid

# Cargar el clasificador Haar para la detección de rostros
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def collect_images(images_path=None):
    cap = cv2.VideoCapture(0)  # Abrir la cámara

    # Establecer una resolución alta para la cámara (ajustar según el dispositivo)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)  # Ancho de resolución
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)  # Altura de resolución

    count_images = 0  # Contador de imágenes guardadas
    saved_images = []  # Lista para almacenar las imágenes guardadas

    # Definir padding (margen) alrededor del rostro
    padding = 25  # Margen adicional para evitar cortes bruscos en el rostro

    # Bucle para capturar imágenes
    while cap.isOpened():
        ret, frame = cap.read()  # Leer cada frame de la cámara
        if not ret:
            print("No se pudo acceder a la cámara.")
            break

        # Convertir el frame a escala de grises para mejorar la detección
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Detectar rostros en el frame
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)  # Ajustar parámetros para detección

        # Mostrar rectángulos alrededor de los rostros detectados en el frame
        display_frame = frame.copy()  # Copiar el frame original solo para mostrar
        for (x, y, w, h) in faces:
            # Añadir padding alrededor del rostro
            x1 = max(0, x - padding)
            y1 = max(0, y - padding)
            x2 = min(frame.shape[1], x + w + padding)
            y2 = min(frame.shape[0], y + h + padding)
            
            # Dibujar un rectángulo con padding alrededor del rostro
            cv2.rectangle(display_frame, (x1, y1), (x2, y2), (255, 0, 0), 2)

        # Mostrar la imagen con la detección de rostros (solo para visualización)
        cv2.imshow('Image Collection - Press "p" to capture', display_frame)
        key = cv2.waitKey(1) & 0xFF

        # Guardar el rostro si se presiona 'p'
        if key == ord('p'):
            if len(faces) > 0:  # Verificar si se detectó al menos un rostro
                for (x, y, w, h) in faces:
                    # Recortar el rostro con padding
                    x1 = max(0, x - padding)
                    y1 = max(0, y - padding)
                    x2 = min(frame.shape[1], x + w + padding)
                    y2 = min(frame.shape[0], y + h + padding)

                    # Recortar la imagen del rostro
                    face_img = frame[y1:y2, x1:x2]
                    
                    # Guardar la imagen solo si se proporciona una ruta
                    if images_path is not None:
                        imgname = os.path.join(images_path, f'{uuid.uuid1()}.jpg')  # Generar un nombre único
                        cv2.imwrite(imgname, face_img, [cv2.IMWRITE_JPEG_QUALITY, 95])  # Guardar con calidad alta
                        count_images += 1
                        saved_images.append(face_img)  # Añadir la imagen guardada a la lista
                        print(f'Imagen guardada: {imgname}')
                    else:
                        # Si no se proporciona una ruta, solo añadir la imagen a la lista
                        saved_images.append(face_img)  # Añadir la imagen a la lista sin guardarla
                        print('Imagen capturada (no guardada).')

            else:
                print("No se detectó ningún rostro para guardar.")

        # Salir si se presiona 'q'
        elif key == ord('q'):
            break

    # Liberar la cámara y cerrar todas las ventanas
    cap.release()  
    cv2.destroyAllWindows()  
    
    # Devolver tanto el contador de imágenes como la lista de imágenes guardadas
    return count_images, saved_images

# %%
import os
import ipywidgets as widgets
from IPython.display import display, clear_output

def setup_image_collection(collect_images_flag):
    # Verificar si el flag está en False, si es así, no hacer nada
    if not collect_images_flag:
        print("Collecting images is not enabled.")
        return  # Terminar la función sin hacer nada

    # Function that is triggered when the "Yes" or "No" button is pressed
    def on_decision_button_clicked(button):
        clear_output()  # Clear the current output (hide previous buttons)
        if button.description == "Yes":
            # If "Yes" is chosen, show the text box for folder name and the "Accept" button
            display(folder_name_label, folder_name_widget, accept_button)
        else:
            # If "No" is chosen, end the flow
            print("No folder will be created.")

    # Function that is triggered when the "Accept" button is pressed
    def on_accept_button_clicked(button):
        folder_selected = data_dir  # Here you can select a default path
        folder_name = folder_name_widget.value
        
        if folder_name:
            new_folder_path = os.path.join(folder_selected, folder_name)
            os.makedirs(new_folder_path, exist_ok=True)
            print(f"Folder created: {new_folder_path}")
            if collect_images_flag:
                collect_images(new_folder_path)  # Call your processing function
        else:
            print("No folder name was entered.")

    # Widgets
    decision_label = widgets.Label("Do you want to create a new folder for the images?")
    yes_button = widgets.Button(description="Yes", button_style='success')
    no_button = widgets.Button(description="No", button_style='danger')

    folder_name_label = widgets.Label("Enter the name of the new folder:")
    folder_name_widget = widgets.Text(placeholder="Enter the folder name")
    accept_button = widgets.Button(description="Accept", button_style='info')

    # Link buttons to their functions
    yes_button.on_click(on_decision_button_clicked)
    no_button.on_click(on_decision_button_clicked)
    accept_button.on_click(on_accept_button_clicked)

    # Display the "Yes" and "No" buttons since collect_images_flag is True
    display(decision_label, yes_button, no_button)

# Ejemplo de cómo llamar la función
#collect_images_flag = True 
setup_image_collection(collect_images_flag)
# Out:
# Collecting images is not enabled.

# %% [markdown]
# # Data Augmentation

# %%
def data_aug(img, num_variations=1):
    data = []
    for i in range(num_variations):
        img_aug = tf.image.stateless_random_brightness(img, max_delta=0.02, seed=(1, 2))
        img_aug = tf.image.stateless_random_contrast(img_aug, lower=0.6, upper=1, seed=(1, 3))
        img_aug = tf.image.stateless_random_flip_left_right(img_aug, seed=(np.random.randint(100), np.random.randint(100)))
        img_aug = tf.image.stateless_random_jpeg_quality(img_aug, min_jpeg_quality=90, max_jpeg_quality=100, seed=(np.random.randint(100), np.random.randint(100)))
        img_aug = tf.image.stateless_random_saturation(img_aug, lower=0.9, upper=1, seed=(np.random.randint(100), np.random.randint(100)))
        data.append(img_aug)
    
    return data

def log_processed_person(log_file, person_name):
    try:
        # Verificar si el archivo existe antes de abrirlo
        if not os.path.exists(log_file):
            with open(log_file, 'w') as f:
                pass  # Crea el archivo si no existe
        
        with builtins.open(log_file, 'a') as f:
            f.write(person_name + '\n')
    except OSError as e:
        print(f"Error al escribir en el archivo de log: {e}")

def augment_in_directory(directory, num_variations):
    if os.path.exists(directory):
        for file_name in os.listdir(directory):
            img_path = os.path.join(directory, file_name)

            # Verifica que sea un archivo de imagen
            if os.path.isfile(img_path) and file_name.lower().endswith(('.jpg', '.png', '.jpeg')):
                # Lee la imagen
                img = cv2.imread(img_path)

                if img is None:
                    print(f"Error al cargar la imagen: {img_path}")
                    continue

                # Aplica aumentación
                augmented_images = data_aug(tf.convert_to_tensor(img), num_variations)

                # Guarda las imágenes aumentadas
                for image in augmented_images:
                    # Convertir tensor a numpy
                    image_np = image.numpy()

                    # Asegúrate de que la imagen esté en formato uint8
                    if image_np.dtype != np.uint8:
                        image_np = (image_np * 255).astype(np.uint8)  # Convertir a uint8

                    # Genera un nombre único para la imagen nueva
                    new_file_name = '{}.jpg'.format(uuid.uuid1())

                    # Guarda la imagen en formato jpg
                    cv2.imwrite(os.path.join(directory, new_file_name), image_np)

def augment_images_in_directories(images_path, log_file='augmentation_log.txt', num_variations=1):
    # Leer los nombres de las personas ya procesadas del archivo de log
    processed_people = set()
    try:
        # Crear el archivo de log si no existe
        if not os.path.exists(log_file):
            with builtins.open(log_file, 'w') as f:
                pass  # Crea el archivo si no existe
        
        with builtins.open(log_file, 'r') as f:
            processed_people = {line.strip() for line in f.readlines()}
    except OSError as e:
        print(f"Error al leer el archivo de log: {e}")
        # Si no se puede leer, comenzamos con un conjunto vacío

    for person_name in os.listdir(images_path):
        person_dir = os.path.join(images_path, person_name)

        # Verifica si es un directorio y si ya se procesó esta persona
        if os.path.isdir(person_dir) and person_name not in processed_people:
            print(f"Aplicando aumentación a: {person_name}")

            # Aumenta las imágenes en el directorio
            augment_in_directory(person_dir, num_variations)

            # Registrar el nombre de la persona en el archivo de log
            log_processed_person(log_file, person_name)

        else:
            print(f"Ya se aplicó aumentación a: {person_name}, omitiendo...")

    print("Aumentación completada.")

# %%
augment_images_in_directories(data_dir)
# Out:
# Ya se aplicó aumentación a: Sergio_Vieira_De_Mello, omitiendo...
# Ya se aplicó aumentación a: Vojislav_Kostunica, omitiendo...
# Ya se aplicó aumentación a: Michael_Douglas, omitiendo...
# Ya se aplicó aumentación a: Vincent_Brooks, omitiendo...
# Ya se aplicó aumentación a: Amelie_Mauresmo, omitiendo...
# Ya se aplicó aumentación a: Naji_Sabri, omitiendo...
# Ya se aplicó aumentación a: Junichiro_Koizumi, omitiendo...
# Ya se aplicó aumentación a: Ricardo_Sanchez, omitiendo...
# Ya se aplicó aumentación a: William_Donaldson, omitiendo...
# Ya se aplicó aumentación a: Costas_Simitis, omitiendo...
# Ya se aplicó aumentación a: Antonio_Palocci, omitiendo...
# Ya se aplicó aumentación a: Gunter_Pleuger, omitiendo...
# Ya se aplicó aumentación a: Renee_Zellweger, omitiendo...
# Ya se aplicó aumentación a: Richard_Myers, omitiendo...
# Ya se aplicó aumentación a: Cameron_Diaz, omitiendo...
# Ya se aplicó aumentación a: John_Kerry, omitiendo...
# Ya se aplicó aumentación a: Marco_Antonio_Barrera, omitiendo...
# Ya se aplicó aumentación a: Angela_Bassett, omitiendo...
# Ya se aplicó aumentación a: Thomas_OBrien, omitiendo...
# Ya se aplicó aumentación a: John_Bolton, omitiendo...
# Ya se aplicó aumentación a: Geoff_Hoon, omitiendo...
# Ya se aplicó aumentación a: Paul_Burrell, omitiendo...
# Ya se aplicó aumentación a: Jesse_Jackson, omitiendo...
# Ya se aplicó aumentación a: Dennis_Kucinich, omitiendo...
# Ya se aplicó aumentación a: Alvaro_Uribe, omitiendo...
# Ya se aplicó aumentación a: Lleyton_Hewitt, omitiendo...
# Ya se aplicó aumentación a: Keanu_Reeves, omitiendo...
# Ya se aplicó aumentación a: Kate_Hudson, omitiendo...
# Ya se aplicó aumentación a: Shimon_Peres, omitiendo...
# Ya se aplicó aumentación a: Zinedine_Zidane, omitiendo...
# Ya se aplicó aumentación a: William_Ford_Jr, omitiendo...
# Ya se aplicó aumentación a: Leonid_Kuchma, omitiendo...
# Ya se aplicó aumentación a: Anna_Kournikova, omitiendo...
# Ya se aplicó aumentación a: Colin_Farrell, omitiendo...
# Ya se aplicó aumentación a: Venus_Williams, omitiendo...
# Ya se aplicó aumentación a: Donald_Rumsfeld, omitiendo...
# Ya se aplicó aumentación a: Oscar_De_La_Hoya, omitiendo...
# Ya se aplicó aumentación a: Zhu_Rongji, omitiendo...
# Ya se aplicó aumentación a: Tim_Henman, omitiendo...
# Ya se aplicó aumentación a: John_Paul_II, omitiendo...
# Ya se aplicó aumentación a: Charles_Moose, omitiendo...
# Ya se aplicó aumentación a: Gray_Davis, omitiendo...
# Ya se aplicó aumentación a: Bill_McBride, omitiendo...
# Ya se aplicó aumentación a: Catherine_Zeta-Jones, omitiendo...
# Ya se aplicó aumentación a: Luiz_Inacio_Lula_da_Silva, omitiendo...
# Ya se aplicó aumentación a: Sheryl_Crow, omitiendo...
# Ya se aplicó aumentación a: Jacques_Rogge, omitiendo...
# Ya se aplicó aumentación a: Halle_Berry, omitiendo...
# Ya se aplicó aumentación a: Carlos_Moya, omitiendo...
# Ya se aplicó aumentación a: Goldie_Hawn, omitiendo...
# Ya se aplicó aumentación a: Robert_Redford, omitiendo...
# Ya se aplicó aumentación a: Hu_Jintao, omitiendo...
# Ya se aplicó aumentación a: Yao_Ming, omitiendo...
# Ya se aplicó aumentación a: Elton_John, omitiendo...
# Ya se aplicó aumentación a: Yoko_Ono, omitiendo...
# Ya se aplicó aumentación a: George_Clooney, omitiendo...
# Ya se aplicó aumentación a: David_Wells, omitiendo...
# Ya se aplicó aumentación a: Robert_Blake, omitiendo...
# Ya se aplicó aumentación a: Wen_Jiabao, omitiendo...
# Ya se aplicó aumentación a: Mike_Weir, omitiendo...
# Ya se aplicó aumentación a: Britney_Spears, omitiendo...
# Ya se aplicó aumentación a: Lance_Armstrong, omitiendo...
# Ya se aplicó aumentación a: Al_Gore, omitiendo...
# Ya se aplicó aumentación a: Mohamed_ElBaradei, omitiendo...
# Ya se aplicó aumentación a: Mohammad_Khatami, omitiendo...
# Ya se aplicó aumentación a: Saddam_Hussein, omitiendo...
# Ya se aplicó aumentación a: Trent_Lott, omitiendo...
# Ya se aplicó aumentación a: Ari_Fleischer, omitiendo...
# Ya se aplicó aumentación a: Condoleezza_Rice, omitiendo...
# Ya se aplicó aumentación a: Matthew_Perry, omitiendo...
# Ya se aplicó aumentación a: Gerry_Adams, omitiendo...
# Ya se aplicó aumentación a: Bill_Gates, omitiendo...
# Ya se aplicó aumentación a: Fujio_Cho, omitiendo...
# Ya se aplicó aumentación a: Ali_Naimi, omitiendo...
# Ya se aplicó aumentación a: Tom_Cruise, omitiendo...
# Ya se aplicó aumentación a: Jennifer_Capriati, omitiendo...
# Ya se aplicó aumentación a: Fernando_Gonzalez, omitiendo...
# Ya se aplicó aumentación a: Sylvester_Stallone, omitiendo...
# Ya se aplicó aumentación a: Joan_Laporta, omitiendo...
# Ya se aplicó aumentación a: John_Travolta, omitiendo...
# Ya se aplicó aumentación a: Juan_Pablo_Montoya, omitiendo...
# Ya se aplicó aumentación a: Colin_Powell, omitiendo...
# Ya se aplicó aumentación a: Bob_Graham, omitiendo...
# Ya se aplicó aumentación a: Celine_Dion, omitiendo...
# Ya se aplicó aumentación a: Adrien_Brody, omitiendo...
# Ya se aplicó aumentación a: Christine_Todd_Whitman, omitiendo...
# Ya se aplicó aumentación a: Jean_Chretien, omitiendo...
# Ya se aplicó aumentación a: Jacques_Chirac, omitiendo...
# Ya se aplicó aumentación a: Albert_Costa, omitiendo...
# Ya se aplicó aumentación a: Rudolph_Giuliani, omitiendo...
# Ya se aplicó aumentación a: Kim_Ryong-sung, omitiendo...
# Ya se aplicó aumentación a: Tommy_Thompson, omitiendo...
# Ya se aplicó aumentación a: Fidel_Castro, omitiendo...
# Ya se aplicó aumentación a: Larry_Brown, omitiendo...
# Ya se aplicó aumentación a: Paula_Radcliffe, omitiendo...
# Ya se aplicó aumentación a: Jiri_Novak, omitiendo...
# Ya se aplicó aumentación a: Tom_Ridge, omitiendo...
# Ya se aplicó aumentación a: Mahmoud_Abbas, omitiendo...
# Ya se aplicó aumentación a: Mariah_Carey, omitiendo...
# Ya se aplicó aumentación a: James_Blake, omitiendo...
# Ya se aplicó aumentación a: Richard_Gephardt, omitiendo...
# Ya se aplicó aumentación a: John_Manley, omitiendo...
# Ya se aplicó aumentación a: Bill_Frist, omitiendo...
# Ya se aplicó aumentación a: Pervez_Musharraf, omitiendo...
# Ya se aplicó aumentación a: Jean_Charest, omitiendo...
# Ya se aplicó aumentación a: Tony_Blair, omitiendo...
# Ya se aplicó aumentación a: Angelina_Jolie, omitiendo...
# Ya se aplicó aumentación a: Rubens_Barrichello, omitiendo...
# Ya se aplicó aumentación a: Bill_Graham, omitiendo...
# Ya se aplicó aumentación a: Hugo_Chavez, omitiendo...
# Ya se aplicó aumentación a: Jean-David_Levitte, omitiendo...
# Ya se aplicó aumentación a: Richard_Armitage, omitiendo...
# Ya se aplicó aumentación a: Jose_Manuel_Durao_Barroso, omitiendo...
# Ya se aplicó aumentación a: Fernando_Henrique_Cardoso, omitiendo...
# Ya se aplicó aumentación a: Queen_Elizabeth_II, omitiendo...
# Ya se aplicó aumentación a: Kim_Dae-jung, omitiendo...
# Ya se aplicó aumentación a: Yasser_Arafat, omitiendo...
# Ya se aplicó aumentación a: Jimmy_Carter, omitiendo...
# Ya se aplicó aumentación a: Robert_De_Niro, omitiendo...
# Ya se aplicó aumentación a: Nestor_Kirchner, omitiendo...
# Ya se aplicó aumentación a: Hamid_Karzai, omitiendo...
# Ya se aplicó aumentación a: Silvio_Berlusconi, omitiendo...
# Ya se aplicó aumentación a: Paul_Bremer, omitiendo...
# Ya se aplicó aumentación a: Ray_Romano, omitiendo...
# Ya se aplicó aumentación a: Rick_Perry, omitiendo...
# Ya se aplicó aumentación a: Joe_Lieberman, omitiendo...
# Ya se aplicó aumentación a: Heizo_Takenaka, omitiendo...
# Ya se aplicó aumentación a: Megawati_Sukarnoputri, omitiendo...
# Ya se aplicó aumentación a: Roger_Federer, omitiendo...
# Ya se aplicó aumentación a: Recep_Tayyip_Erdogan, omitiendo...
# Ya se aplicó aumentación a: Tariq_Aziz, omitiendo...
# Ya se aplicó aumentación a: Guillermo_Coria, omitiendo...
# Ya se aplicó aumentación a: Hillary_Clinton, omitiendo...
# Ya se aplicó aumentación a: Robert_Duvall, omitiendo...
# Ya se aplicó aumentación a: Lucio_Gutierrez, omitiendo...
# Ya se aplicó aumentación a: Holly_Hunter, omitiendo...
# Ya se aplicó aumentación a: Jeong_Se-hyun, omitiendo...
# Ya se aplicó aumentación a: Spencer_Abraham, omitiendo...
# Ya se aplicó aumentación a: Clint_Eastwood, omitiendo...
# Ya se aplicó aumentación a: George_HW_Bush, omitiendo...
# Ya se aplicó aumentación a: Hans_Blix, omitiendo...
# Ya se aplicó aumentación a: Sarah_Hughes, omitiendo...
# Ya se aplicó aumentación a: Hugh_Grant, omitiendo...
# Ya se aplicó aumentación a: Susan_Sarandon, omitiendo...
# Ya se aplicó aumentación a: Rob_Marshall, omitiendo...
# Ya se aplicó aumentación a: Roh_Moo-hyun, omitiendo...
# Ya se aplicó aumentación a: Naomi_Watts, omitiendo...
# Ya se aplicó aumentación a: Diana_Krall, omitiendo...
# Ya se aplicó aumentación a: Jon_Gruden, omitiendo...
# Ya se aplicó aumentación a: Sophia_Loren, omitiendo...
# Ya se aplicó aumentación a: Andy_Roddick, omitiendo...
# Ya se aplicó aumentación a: Michael_Jackson, omitiendo...
# Ya se aplicó aumentación a: Boris_Becker, omitiendo...
# Ya se aplicó aumentación a: Bob_Stoops, omitiendo...
# Ya se aplicó aumentación a: Tony_Stewart, omitiendo...
# Ya se aplicó aumentación a: Alejandro_Toledo, omitiendo...
# Ya se aplicó aumentación a: Kim_Clijsters, omitiendo...
# Ya se aplicó aumentación a: Billy_Crystal, omitiendo...
# Ya se aplicó aumentación a: Romano_Prodi, omitiendo...
# Ya se aplicó aumentación a: Edward_Lu, omitiendo...
# Ya se aplicó aumentación a: Jay_Garner, omitiendo...
# Ya se aplicó aumentación a: Nancy_Pelosi, omitiendo...
# Ya se aplicó aumentación a: Yoriko_Kawaguchi, omitiendo...
# Ya se aplicó aumentación a: Mike_Myers, omitiendo...
# Ya se aplicó aumentación a: Pete_Sampras, omitiendo...
# Ya se aplicó aumentación a: Thaksin_Shinawatra, omitiendo...
# Ya se aplicó aumentación a: Jennifer_Aniston, omitiendo...
# Ya se aplicó aumentación a: Hosni_Mubarak, omitiendo...
# Ya se aplicó aumentación a: Tom_Daschle, omitiendo...
# Ya se aplicó aumentación a: Jim_Furyk, omitiendo...
# Ya se aplicó aumentación a: Howard_Dean, omitiendo...
# Ya se aplicó aumentación a: Yashwant_Sinha, omitiendo...
# Ya se aplicó aumentación a: Cesar_Gaviria, omitiendo...
# Ya se aplicó aumentación a: Winona_Ryder, omitiendo...
# Ya se aplicó aumentación a: Nicole_Kidman, omitiendo...
# Ya se aplicó aumentación a: Ralf_Schumacher, omitiendo...
# Ya se aplicó aumentación a: Tang_Jiaxuan, omitiendo...
# Ya se aplicó aumentación a: Paul_Martin, omitiendo...
# Ya se aplicó aumentación a: Steve_Lavin, omitiendo...
# Ya se aplicó aumentación a: Norm_Coleman, omitiendo...
# Ya se aplicó aumentación a: John_Abizaid, omitiendo...
# Ya se aplicó aumentación a: James_Kelly, omitiendo...
# Ya se aplicó aumentación a: Binyamin_Ben-Eliezer, omitiendo...
# Ya se aplicó aumentación a: Ron_Dittemore, omitiendo...
# Ya se aplicó aumentación a: Clay_Aiken, omitiendo...
# Ya se aplicó aumentación a: Mike_Martz, omitiendo...
# Ya se aplicó aumentación a: Steven_Spielberg, omitiendo...
# Ya se aplicó aumentación a: Ariel_Sharon, omitiendo...
# Ya se aplicó aumentación a: Elsa_Zylberstein, omitiendo...
# Ya se aplicó aumentación a: Laura_Bush, omitiendo...
# Ya se aplicó aumentación a: Tommy_Franks, omitiendo...
# Ya se aplicó aumentación a: Jelena_Dokic, omitiendo...
# Ya se aplicó aumentación a: Li_Peng, omitiendo...
# Ya se aplicó aumentación a: Gordon_Brown, omitiendo...
# Ya se aplicó aumentación a: Jonathan_Edwards, omitiendo...
# Ya se aplicó aumentación a: John_McCain, omitiendo...
# Ya se aplicó aumentación a: Mike_Krzyzewski, omitiendo...
# Ya se aplicó aumentación a: Monica_Seles, omitiendo...
# Ya se aplicó aumentación a: Joschka_Fischer, omitiendo...
# Ya se aplicó aumentación a: Jose_Maria_Aznar, omitiendo...
# Ya se aplicó aumentación a: Natalie_Coughlin, omitiendo...
# Ya se aplicó aumentación a: Dennis_Hastert, omitiendo...
# Ya se aplicó aumentación a: Nicanor_Duarte_Frutos, omitiendo...
# Ya se aplicó aumentación a: Abdullah_Gul, omitiendo...
# Ya se aplicó aumentación a: Mahathir_Mohamad, omitiendo...
# Ya se aplicó aumentación a: Gonzalo_Sanchez_de_Lozada, omitiendo...
# Ya se aplicó aumentación a: Edmund_Stoiber, omitiendo...
# Ya se aplicó aumentación a: Amelia_Vega, omitiendo...
# Ya se aplicó aumentación a: Luis_Ernesto_Derbez_Bautista, omitiendo...
# Ya se aplicó aumentación a: David_Nalbandian, omitiendo...
# Ya se aplicó aumentación a: Bill_Clinton, omitiendo...
# Ya se aplicó aumentación a: Jose_Serra, omitiendo...
# Ya se aplicó aumentación a: Bob_Hope, omitiendo...
# Ya se aplicó aumentación a: Michael_Schumacher, omitiendo...
# Ya se aplicó aumentación a: Lindsay_Davenport, omitiendo...
# Ya se aplicó aumentación a: Tommy_Haas, omitiendo...
# Ya se aplicó aumentación a: Jan_Ullrich, omitiendo...
# Ya se aplicó aumentación a: Gwyneth_Paltrow, omitiendo...
# Ya se aplicó aumentación a: Serena_Williams, omitiendo...
# Ya se aplicó aumentación a: Martin_Scorsese, omitiendo...
# Ya se aplicó aumentación a: Mohammed_Al-Douri, omitiendo...
# Ya se aplicó aumentación a: Michael_Bloomberg, omitiendo...
# Ya se aplicó aumentación a: Norah_Jones, omitiendo...
# Ya se aplicó aumentación a: John_Edwards, omitiendo...
# Ya se aplicó aumentación a: Bulent_Ecevit, omitiendo...
# Ya se aplicó aumentación a: John_Allen_Muhammad, omitiendo...
# Ya se aplicó aumentación a: Arnold_Schwarzenegger, omitiendo...
# Ya se aplicó aumentación a: Tiger_Woods, omitiendo...
# Ya se aplicó aumentación a: Muhammad_Ali, omitiendo...
# Ya se aplicó aumentación a: Ricardo_Lagos, omitiendo...
# Ya se aplicó aumentación a: Sarah_Jessica_Parker, omitiendo...
# Ya se aplicó aumentación a: Carmen_Electra, omitiendo...
# Ya se aplicó aumentación a: Mark_Philippoussis, omitiendo...
# Ya se aplicó aumentación a: Jason_Kidd, omitiendo...
# Ya se aplicó aumentación a: John_Howard, omitiendo...
# Ya se aplicó aumentación a: Tung_Chee-hwa, omitiendo...
# Ya se aplicó aumentación a: Sergey_Lavrov, omitiendo...
# Ya se aplicó aumentación a: Dominique_de_Villepin, omitiendo...
# Ya se aplicó aumentación a: Valentino_Rossi, omitiendo...
# Ya se aplicó aumentación a: Calista_Flockhart, omitiendo...
# Ya se aplicó aumentación a: Atal_Bihari_Vajpayee, omitiendo...
# Ya se aplicó aumentación a: Julie_Gerberding, omitiendo...
# Ya se aplicó aumentación a: John_Ashcroft, omitiendo...
# Ya se aplicó aumentación a: Vladimir_Putin, omitiendo...
# Ya se aplicó aumentación a: Vicente_Fox, omitiendo...
# Ya se aplicó aumentación a: Jeremy_Greenstock, omitiendo...
# Ya se aplicó aumentación a: Richard_Virenque, omitiendo...
# Ya se aplicó aumentación a: Jiang_Zemin, omitiendo...
# Ya se aplicó aumentación a: Charlton_Heston, omitiendo...
# Ya se aplicó aumentación a: Roman_Polanski, omitiendo...
# Ya se aplicó aumentación a: Liza_Minnelli, omitiendo...
# Ya se aplicó aumentación a: Kofi_Annan, omitiendo...
# Ya se aplicó aumentación a: Michael_Chang, omitiendo...
# Ya se aplicó aumentación a: Kamal_Kharrazi, omitiendo...
# Ya se aplicó aumentación a: Maria_Shriver, omitiendo...
# Ya se aplicó aumentación a: Paul_ONeill, omitiendo...
# Ya se aplicó aumentación a: Dick_Cheney, omitiendo...
# Ya se aplicó aumentación a: Gloria_Macapagal_Arroyo, omitiendo...
# Ya se aplicó aumentación a: Al_Sharpton, omitiendo...
# Ya se aplicó aumentación a: George_W_Bush, omitiendo...
# Ya se aplicó aumentación a: Ann_Veneman, omitiendo...
# Ya se aplicó aumentación a: JK_Rowling, omitiendo...
# Ya se aplicó aumentación a: Ana_Guevara, omitiendo...
# Ya se aplicó aumentación a: Meryl_Streep, omitiendo...
# Ya se aplicó aumentación a: Jack_Straw, omitiendo...
# Ya se aplicó aumentación a: David_Beckham, omitiendo...
# Ya se aplicó aumentación a: Silvan_Shalom, omitiendo...
# Ya se aplicó aumentación a: Vaclav_Havel, omitiendo...
# Ya se aplicó aumentación a: Carlos_Menem, omitiendo...
# Ya se aplicó aumentación a: Andre_Agassi, omitiendo...
# Ya se aplicó aumentación a: Javier_Solana, omitiendo...
# Ya se aplicó aumentación a: Salma_Hayek, omitiendo...
# Ya se aplicó aumentación a: George_Robertson, omitiendo...
# Ya se aplicó aumentación a: Pedro_Almodovar, omitiendo...
# Ya se aplicó aumentación a: Tom_Hanks, omitiendo...
# Ya se aplicó aumentación a: Arminio_Fraga, omitiendo...
# Ya se aplicó aumentación a: Roy_Moore, omitiendo...
# Ya se aplicó aumentación a: John_Negroponte, omitiendo...
# Ya se aplicó aumentación a: Jean-Pierre_Raffarin, omitiendo...
# Ya se aplicó aumentación a: Julianne_Moore, omitiendo...
# Ya se aplicó aumentación a: Jeb_Bush, omitiendo...
# Ya se aplicó aumentación a: Paul_McCartney, omitiendo...
# Ya se aplicó aumentación a: Michelle_Kwan, omitiendo...
# Ya se aplicó aumentación a: Paul_Wolfowitz, omitiendo...
# Ya se aplicó aumentación a: Pierce_Brosnan, omitiendo...
# Ya se aplicó aumentación a: Bill_Simon, omitiendo...
# Ya se aplicó aumentación a: Harrison_Ford, omitiendo...
# Ya se aplicó aumentación a: Charles_Taylor, omitiendo...
# Ya se aplicó aumentación a: Justine_Pasek, omitiendo...
# Ya se aplicó aumentación a: John_Snow, omitiendo...
# Ya se aplicó aumentación a: Eduardo_Duhalde, omitiendo...
# Ya se aplicó aumentación a: Valery_Giscard_dEstaing, omitiendo...
# Ya se aplicó aumentación a: Li_Zhaoxing, omitiendo...
# Ya se aplicó aumentación a: Leonardo_DiCaprio, omitiendo...
# Ya se aplicó aumentación a: Kevin_Costner, omitiendo...
# Ya se aplicó aumentación a: Richard_Gere, omitiendo...
# Ya se aplicó aumentación a: Ian_Thorpe, omitiendo...
# Ya se aplicó aumentación a: Jackie_Chan, omitiendo...
# Ya se aplicó aumentación a: Ana_Palacio, omitiendo...
# Ya se aplicó aumentación a: Walter_Mondale, omitiendo...
# Ya se aplicó aumentación a: Robert_Zoellick, omitiendo...
# Ya se aplicó aumentación a: Igor_Ivanov, omitiendo...
# Ya se aplicó aumentación a: Jennifer_Lopez, omitiendo...
# Ya se aplicó aumentación a: Jennifer_Garner, omitiendo...
# Ya se aplicó aumentación a: Juan_Carlos_Ferrero, omitiendo...
# Ya se aplicó aumentación a: Luis_Horna, omitiendo...
# Ya se aplicó aumentación a: Ben_Affleck, omitiendo...
# Ya se aplicó aumentación a: Paradorn_Srichaphan, omitiendo...
# Ya se aplicó aumentación a: Gerhard_Schroeder, omitiendo...
# Ya se aplicó aumentación a: Taha_Yassin_Ramadan, omitiendo...
# Ya se aplicó aumentación a: Justin_Timberlake, omitiendo...
# Aumentación completada.

# %% [markdown]
# # Preparing Datasets for Training

# %%
import os
import tensorflow as tf
import random

def _bytes_feature(value):
    """Returns a bytes_list from a string / byte."""
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[tf.io.encode_jpeg(value).numpy()]))

def _int64_feature(value):
    """Returns an int64_list from a bool / enum / int."""
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

def create_example(image1, image2, label):
    feature = {
        'image1': _bytes_feature(image1),
        'image2': _bytes_feature(image2),
        'label': _int64_feature(label)
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))

def save_dataset_as_tfrecord(dataset, save_path):
    """Guarda el dataset como TFRecord"""
    with tf.io.TFRecordWriter(save_path) as writer:
        for image1, image2, label in dataset:
            example = create_example(image1, image2, label)
            writer.write(example.SerializeToString())

def load_dataset_from_tfrecord(tfrecord_path):
    """Carga el dataset desde un archivo TFRecord"""
    raw_dataset = tf.data.TFRecordDataset(tfrecord_path)
    
    # Deserializar los datos
    feature_description = {
        'image1': tf.io.FixedLenFeature([], tf.string),
        'image2': tf.io.FixedLenFeature([], tf.string),
        'label': tf.io.FixedLenFeature([], tf.int64),
    }

    def _parse_function(example_proto):
        parsed_example = tf.io.parse_single_example(example_proto, feature_description)
        image1 = tf.io.decode_jpeg(parsed_example['image1'], channels=3)
        image2 = tf.io.decode_jpeg(parsed_example['image2'], channels=3)
        label = parsed_example['label']
        return (image1, image2), label

    return raw_dataset.map(_parse_function)

def create_or_load_dataset(data_dir, save_path):
    # Si el archivo TFRecord ya existe, cargarlo
    if os.path.exists(save_path):
        print(f'Dataset cargado desde {save_path}')
        return load_dataset_from_tfrecord(save_path)

    # Obtener las carpetas de personas
    person_folders = [os.path.join(data_dir, folder) for folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, folder))]

    # Definimos los datasets
    positive_pairs = []
    negative_pairs = []

    # Generar pares positivos y negativos
    for i in range(len(person_folders)):
        # Listar las imágenes en la carpeta de la persona i
        images_i = tf.data.Dataset.list_files(os.path.join(person_folders[i], '*.jpg')).as_numpy_iterator()

        # Crear pares positivos (n * (n - 1) / 2)
        images_i = list(images_i)
        for j in range(8):
            for k in range(j + 1, j + 4):
                positive_pairs.append((images_i[j], images_i[k], 1))  # Etiqueta 1 para pares positivos

        # Crear pares negativos con otras personas
        for j in range(len(person_folders)):
            if i != j:  # Asegurarse de no tomar la misma carpeta
                images_j = tf.data.Dataset.list_files(os.path.join(person_folders[j], '*.jpg')).as_numpy_iterator()
                images_j = list(images_j)
                index_i = random.randint(0, len(images_i) - 1)
                index_j = random.randint(0, len(images_j) - 1)

                negative_pairs.append((images_i[index_i], images_j[index_j], 0))  # Etiqueta 0 para pares negativos

    # Preprocesar las imágenes
    def preprocess_image(image_path):
        byte_img = tf.io.read_file(image_path)
        img = tf.io.decode_jpeg(byte_img, channels=3)  # Asegura que la imagen tenga 3 canales (RGB)
        img = tf.image.resize(img, (105, 105))
        img = img / 255.0  # Normaliza los valores de los píxeles a [0, 1]
        return img

    # Preprocesar y almacenar las imágenes como pares
    processed_positive_pairs = [(preprocess_image(x), preprocess_image(y), label) for x, y, label in positive_pairs]
    processed_negative_pairs = [(preprocess_image(x), preprocess_image(y), label) for x, y, label in negative_pairs]

    # Crear datasets de TensorFlow a partir de los pares
    dataset = processed_positive_pairs + processed_negative_pairs
    random.shuffle(dataset)  # Mezclar el dataset antes de guardarlo

    # Guardar el dataset como TFRecord
    save_dataset_as_tfrecord(dataset, save_path)
    print(f'Dataset guardado en {save_path}')
    
    return tf.data.Dataset.from_tensor_slices(dataset)

# Ejemplo de uso
save_path = 'dataset.tfrecord'
dataset = create_or_load_dataset(data_dir,save_path)
# Out:
# <_MapDataset element_spec=((TensorSpec(shape=(105, 105, 3), dtype=tf.float32, name=None), TensorSpec(shape=(105, 105, 3), dtype=tf.float32, name=None)), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
# Obtener la cardinalidad del dataset
dataset_size = dataset.cardinality().numpy()
print(dataset_size)

# Verificar si el dataset es finito o infinito
if dataset_size == tf.data.experimental.INFINITE_CARDINALITY:
    print("El dataset es infinito.")
elif dataset_size == tf.data.experimental.UNKNOWN_CARDINALITY:
    print("El tamaño del dataset es desconocido.")
else:
    # Toma el 70% del conjunto de datos para entrenamiento
    train_size = round(dataset_size * 0.7)
    train_data = dataset.take(train_size)

    # Optimización de recursos: Agrupa los elementos en lotes de 16
    train_data = train_data.batch(16)

    # Superpone el procesamiento y entrenamiento con prefetch de 8 lotes
    train_data = train_data.prefetch(8)

    print(f"Tamaño del conjunto de entrenamiento: {train_size}")
# Out:
# -2
# El tamaño del dataset es desconocido.

# %% [markdown]
# ### Test dataset

# %%
test_data = dataset.skip(round(len(dataset)*.7))
test_data = test_data.take(round(len(dataset)*.3))
test_data = test_data.batch(16)
test_data = test_data.prefetch(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 test_data = dataset.skip(round(len(dataset)*.7))
#       2 test_data = test_data.take(round(len(dataset)*.3))
#       3 test_data = test_data.batch(16)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:533, in DatasetV2.__len__(self)
#     531   raise TypeError("The dataset is infinite.")
#     532 if length.numpy() == UNKNOWN:
# --> 533   raise TypeError("The dataset length is unknown.")
#     534 return length
#
# TypeError: The dataset length is unknown.

# %% [markdown]
# # Embedding Model Definition
#
# ### Input Layer
#
# - **Input(shape=(105, 105, 3))**: Esta es la capa de entrada del modelo. Recibe imágenes de tamaño **105x105** con **3 canales** (RGB).
#
# ---
#
# ### Primera Capa Convolucional + MaxPooling
#
# - **Conv2D(64, (10, 10), activation='relu')**: Esta es una **capa convolucional** que aplica **64 filtros** a la imagen de entrada, cada uno de tamaño **10x10**. La función de activación utilizada es **ReLU**, que introduce no linealidad en la red.
#   - **Entrada**: Imagen de tamaño **105x105x3** (alto x ancho x canales).
#   - **Salida**: Un conjunto de características (**feature maps**) de tamaño reducido pero con más **canales (profundidad)**, lo que permite que la red aprenda características más complejas.
#
# - **MaxPooling2D(pool_size=(2, 2), padding='same')**: Esta es una **capa de reducción de dimensión espacial** que actúa sobre las características extraídas por las capas convolucionales anteriores. Su función principal es **reducir el tamaño** de las representaciones espaciales (ancho y alto) para disminuir la cantidad de parámetros, lo que ayuda a evitar el sobreajuste y mejora la eficiencia computacional.
#   - **Función**: Toma el valor máximo en regiones de **2x2 píxeles** de las características (feature maps) obtenidas de la convolución. Esto permite reducir la resolución espacial mientras se conservan las características más importantes.
#   - **pool_size=(2, 2)**: La ventana es de **2x2**, reduciendo el tamaño de la imagen en un factor de 2.
#   - **padding='same'**: Mantiene las dimensiones similares a las de la entrada añadiendo relleno cuando es necesario.
#   - **Propósito**: Ayuda a la red a enfocarse en **patrones más globales** en las capas más profundas.
#
# ---
#
# ### Segunda Capa Convolucional + MaxPooling
#
# - **Conv2D(128, (7, 7), activation='relu')**: Aplica **128 filtros** de tamaño **7x7** a las características que vienen de la primera capa de pooling. La activación es nuevamente **ReLU**.
#
# - **MaxPooling2D(pool_size=(2, 2), padding='same')**: Reduce el tamaño espacial aplicando pooling de **2x2**.
#
# ---
#
# ### Tercera Capa Convolucional + MaxPooling
#
# - **Conv2D(128, (4, 4), activation='relu')**: Aplica **128 filtros** de tamaño **4x4** sobre las características.
#
# - **MaxPooling2D(pool_size=(2, 2), padding='same')**: Reduce nuevamente el tamaño espacial aplicando pooling de **2x2**.
#
# ---
#
# ### Cuarta Capa Convolucional + Aplanamiento (Flatten)
#
# - **Conv2D(256, (4, 4), activation='relu')**: Aplica **256 filtros** de tamaño **4x4**. En las capas más profundas, se extraen características más complejas como bordes, texturas y patrones.
#
# - **Flatten()**: Aplana el tensor tridimensional (resultado de la convolución) en un **vector unidimensional** para ser procesado por una capa densa completamente conectada.
#
# ---
#
# ### Capa Densa Completamente Conectada
#
# - **Dense(4096, activation='sigmoid')**: Es una **capa completamente conectada** con **4096 unidades**. La activación sigmoide transforma los valores entre 0 y 1, útil para tareas de similitud, como en redes siamesas donde se comparan embeddings.
#
#   - Esta capa actúa como la **representación final** de la imagen de entrada, produciendo un **vector de tamaño 4096**, que será el **embedding** que representa la imagen.

# %%
# Crea un modelo de red convolucional para obtener una representación o embedding de una imagen de entrada de tamaño 105x105 con 3 canales de color (RGB)

def make_embedding(): 
    # Define la entrada de la red. Aquí se espera una imagen de tamaño 105x105 píxeles con 3 canales (RGB).
    inp = Input(shape=(105, 105, 3), name='input_image')
    # Primera capa convolucional + MaxPooling
    c1 = Conv2D(64, (10, 10), activation='relu')(inp)
    m1 = MaxPooling2D(pool_size=(2, 2), padding='same')(c1)
    # Segunda capa convolucional + MaxPooling
    c2 = Conv2D(128, (7, 7), activation='relu')(m1)
    m2 = MaxPooling2D(pool_size=(2, 2), padding='same')(c2)
    
    c3 = Conv2D(128, (4, 4), activation='relu')(m2)
    m3 = MaxPooling2D(pool_size=(2, 2), padding='same')(c3)
    
    c4 = Conv2D(256, (4, 4), activation='relu')(m3)
    f1 = Flatten()(c4)
    d1 = Dense(4096, activation='sigmoid')(f1)
    
    return Model(inputs=[inp], outputs=d1, name='embedding')

# Se define una red neuronal convolucional (CNN) para extraer embeddings (representaciones de características) de imágenes.

# %% [markdown]
# ## Distancia L1

# %%
# Se define una capa personalizada para calcular la distancia L1 (la suma de las diferencias absolutas) entre dos vectores.

class L1Dist(Layer):
    def __init__(self, **kwargs):
        super().__init__()
       
    def call(self, inputs):
        return tf.abs(inputs[0] - inputs[1])

# %% [markdown]
# # Siamese Model

# %% [markdown]
# Aquí tienes el contenido en formato Markdown, estructurado de manera clara y ordenada:
#
# ```markdown
# # Definición del modelo siamés
#
# ## Función `make_siamese_model()`
#
# La función `make_siamese_model()` define y devuelve un modelo siamés, que se utiliza para comparar dos imágenes y determinar si son similares.
#
# ### Explicación del Código
#
# 1. **Definición de las Entradas**:
#    ```python
#    input_sample_image = Input(shape=(105, 105, 3), name='sample_image')
#    input_validation_image = Input(shape=(105, 105, 3), name='validation_image')
#    ```
#    - Se crean tensores de entrada para las imágenes, cada una con un tamaño de **105x105 píxeles** y **3 canales** (RGB).
#
# 2. **Modelo de Embeddings**:
#    ```python
#    embedding_model = make_embedding()
#    ```
#    - Se llama a la función `make_embedding()` que define el modelo de **embeddings**, responsable de extraer características importantes de las imágenes.
#
# 3. **Codificación de la Imagen de Muestra**:
#    ```python
#    encoded_s = embedding_model(input_sample_image)
#    ```
#    - La imagen de muestra se pasa por el modelo de embeddings, obteniendo un vector de características que representa dicha imagen.
#
# 4. **Codificación de la Imagen de Validación**:
#    ```python
#    encoded_v = embedding_model(input_validation_image)
#    ```
#    - La imagen de validación se codifica para obtener su correspondiente vector de características.
#
# 5. **Cálculo de la Distancia**:
#    ```python
#    distance = L1Dist(name='distance')([encoded_s, encoded_v])
#    ```
#    - Se calcula la **distancia L1** entre los dos embeddings. Esta medida indica la similitud, donde valores más bajos indican mayor similitud.
#
# 6. **Clasificador**:
#    ```python
#    classifier = Dense(1, activation='sigmoid')(distance)
#    ```
#    - Se define una capa densa con una sola unidad y activación **sigmoide**. Produce un valor entre **0 y 1**, representando la probabilidad de que las dos imágenes sean de la misma clase.
#
# 7. **Definición del Modelo Completo**:
#    ```python
#    model = Model(inputs=[input_sample_image, input_validation_image], outputs=classifier, name='siamese_network')
#    ```
#    - Se crea el modelo completo, especificando las entradas y la salida. Se le asigna el nombre `'siamese_network'`.
#
# 8. **Retorno del Modelo**:
#    ```python
#    return model
#    ```
#    - Finalmente, se devuelve el modelo siamés creado.
#
# ---
#
# ## Explicación de las Funciones y Activaciones Utilizadas
#
# ### 1. `Input`
# - **Descripción**: Crea un tensor de entrada para el modelo.
# - **Uso**: Se usa para definir las dimensiones de las imágenes de entrada.
#
# ### 2. `make_embedding()`
# - **Descripción**: Define un modelo que extrae características relevantes de las imágenes.
# - **Uso**: Permite obtener representaciones compactas (embeddings) que encapsulan la información más relevante de las imágenes.
#
# ### 3. `L1Dist`
# - **Descripción**: Calcula la distancia L1 (también conocida como distancia Manhattan) entre dos vectores.
# - **Uso**: Mide la similitud entre los embeddings generados para las dos imágenes. Una distancia más baja indica que las imágenes son más similares.
#
# ### 4. `Dense`
# - **Descripción**: Crea una capa completamente conectada.
# - **Uso**: Se utiliza para combinar las salidas de las capas anteriores en una salida única. En este caso, se utiliza para generar la probabilidad de que las imágenes sean de la misma clase.
#
# ### 5. Función de Activación `sigmoid`
# - **Descripción**: La función sigmoide transforma cualquier valor real en un rango entre 0 y 1.
# - **Uso**: Es ideal para tareas de clasificación binaria, donde queremos una probabilidad de pertenencia a una clase.
#
# ### 6. Funciones de Activación `ReLU`
# - **Descripción**: La función de activación ReLU (Rectified Linear Unit) devuelve 0 si la entrada es menor que 0; de lo contrario, devuelve la entrada.
# - **Uso**: Se utiliza en las capas convolucionales para introducir no linealidad y permitir que la red aprenda características complejas.
#
# ---
#
# ## Resumen
# El modelo siamés construido en esta función compara dos imágenes utilizando un modelo de embeddings para extraer características, calcula la distancia entre estas características y finalmente clasifica si las imágenes son similares o no utilizando una capa densa con activación sigmoide. Las activaciones ReLU se utilizan en las capas convolucionales para facilitar el aprendizaje de características no lineales.
# ```
#
# Este contenido está diseñado para ser claro y fácil de leer, proporcionando una comprensión completa de la función `make_siamese_model()` y las activaciones utilizadas en el modelo.

# %%
def make_siamese_model(): 
    input_sample_image = Input(shape=(105, 105, 3), name='sample_image')
    input_validation_image = Input(shape=(105, 105, 3), name='validation_image')
    
    embedding_model = make_embedding()
    
    encoded_s = embedding_model(input_sample_image)
    encoded_v = embedding_model(input_validation_image)
    
    distance = L1Dist(name='distance')([encoded_s, encoded_v])
    
    classifier = Dense(1, activation='sigmoid')(distance)
    
    model = Model(inputs=[input_sample_image, input_validation_image], outputs=classifier, name='siamese_network')
    
    return model

# %%
siamese_model = make_siamese_model()
siamese_model.summary()
# Out:
# Model: "siamese_network"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sample_image        │ (None, 105, 105,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ validation_image    │ (None, 105, 105,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 4096)      │ 38,960,448 │ sample_image[0][… │
# │ (Functional)        │                   │            │ validation_image… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ l1_dist (L1Dist)    │ (None, 4096)      │          0 │ embedding[0][0],  │
# │                     │                   │            │ embedding[1][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │      4,097 │ l1_dist[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 38,964,545 (148.64 MB)
#  Trainable params: 38,964,545 (148.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### ***Note :***
# > ***I could have chosen a simpler approach using Keras' compile function, but I decided to implement the training process manually.
# This allowed me to understand in detail each step involved in training the model. Although I haven't tested the following code,
# it should work fine. Here's the streamlined approach:***
#
# ```python
#
# siamese_model = make_siamese_model()
# siamese_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[Precision(), Recall()])
#
# history = siamese_model.fit(train_data,
#                             validation_data=test_data,
#                             epochs=5,
#                             batch_size=16)
#
# plt.plot(history.history['precision'], label='Precision')
# plt.plot(history.history['recall'], label='Recall')
# plt.title('Precision and Recall of Siamese Model')
# plt.xlabel('Epochs')
# plt.ylabel('Metrics')
# plt.legend()
# plt.show()
# ```

# %% [markdown]
# # Funciones de Pérdida en Aprendizaje Automático
#
# ## ¿Qué son las Funciones de Pérdida?
#
# Las funciones de pérdida son componentes esenciales en el entrenamiento de redes neuronales. Cuantifican el error entre las predicciones del modelo y las salidas reales, permitiendo al modelo optimizarse para mejorar su rendimiento.
#
# ### Propósitos de las Funciones de Pérdida
#
# 1. **Cuantificación del Error**: Mide la diferencia entre las predicciones del modelo y los valores reales.
# 2. **Guía de Optimización**: Ayuda a actualizar los pesos de la red durante el entrenamiento, minimizando el error.
# 3. **Evaluación del Modelo**: Permite comparar el rendimiento de diferentes modelos.
#
# ---
#
# ## Funciones de Pérdida Comunes en Redes Siamesas
#
# Las redes siamesas están diseñadas para aprender representaciones y medir la similitud entre pares de entradas, por lo que las funciones de pérdida utilizadas en este contexto deben reflejar este objetivo. A continuación se presentan las más comunes:
#
# ### 1. **Contrastive Loss**
#
# - **Uso**: Evalúa la distancia entre dos entradas. Incentiva que las muestras similares estén más cerca en el espacio de embeddings y las disímiles estén más lejos.
#
# - **Fórmula**:
#   \[
#   \text{Loss} = (1 - y) \cdot \frac{1}{2} D^2 + y \cdot \frac{1}{2} \max(0, m - D)^2
#   \]
#   donde:
#   - \( D \) es la distancia entre los embeddings,
#   - \( y \) es la etiqueta (1 para similar, 0 para disímil),
#   - \( m \) es el margen.
#
# - **Funcionamiento**:
#   - Si \( y = 1 \) (pares similares), la pérdida penaliza si la distancia entre los embeddings es grande.
#   - Si \( y = 0 \) (pares disímiles), la pérdida penaliza si los embeddings están demasiado cerca, dentro del margen \( m \).
#
# ---
#
# ### 2. **Triplet Loss**
#
# - **Uso**: Compara tripletas de entradas: un ancla (A), una muestra positiva (P) y una negativa (N). Busca que el ancla esté más cerca del positivo que del negativo por un margen dado.
#
# - **Fórmula**:
#   \[
#   \text{Loss} = \max(0, D(a, p) - D(a, n) + \alpha)
#   \]
#   donde:
#   - \( a \) es el ancla,
#   - \( p \) es la muestra positiva,
#   - \( n \) es la muestra negativa,
#   - \( \alpha \) es un margen.
#
# - **Funcionamiento**:
#   - Penaliza si la distancia entre el ancla y la muestra positiva \( D(a, p) \) es mayor o igual que la distancia entre el ancla y la muestra negativa \( D(a, n) \) más un margen \( \alpha \).
#   - Asegura que las muestras positivas estén más cerca del ancla que las negativas en el espacio de embeddings.
#
# ---
#
# ### 3. **Binary Crossentropy**
#
# - **Uso**: Común en tareas de clasificación binaria. Se puede aplicar en redes siamesas para predecir si dos entradas son similares (1) o no (0).
#
# - **Fórmula**:
#   \[
#   \text{Loss} = -\frac{1}{N} \sum_{i=1}^{N} [y_i \cdot \log(p_i) + (1 - y_i) \cdot \log(1 - p_i)]
#   \]
#   donde:
#   - \( y_i \) es la etiqueta (1 o 0),
#   - \( p_i \) es la probabilidad predicha por el modelo,
#   - \( N \) es el número de ejemplos.
#
# - **Funcionamiento**:
#   - Mide la divergencia entre la probabilidad predicha \( p_i \) y la etiqueta real \( y_i \).
#   - Penaliza las predicciones incorrectas: si el modelo asigna una probabilidad baja a una muestra etiquetada como similar (1), la pérdida será alta, y viceversa.
#
# ---
#
# ### 4. **Hinge Loss**
#
# - **Uso**: Se utiliza en Máquinas de Vectores de Soporte (SVM), pero también es aplicable a redes siamesas. Busca que la diferencia entre las salidas de pares similares y disímiles esté por encima de un margen.
#
# - **Fórmula**:
#   \[
#   \text{Loss} = \max(0, m - (y \cdot D))
#   \]
#   donde:
#   - \( y \) es la etiqueta (1 o -1),
#   - \( D \) es la distancia entre los embeddings,
#   - \( m \) es un margen.
#
# - **Funcionamiento**:
#   - Penaliza si los pares disímiles están demasiado cerca (dentro del margen).
#   - Similar a **Contrastive Loss**, pero no requiere etiquetas binarias (1 o 0) y es más común en clasificación marginada.
#
# ---
#
# ### 5. **Focal Loss**
#
# - **Uso**: Ampliación de la **Binary Crossentropy** para manejar clases desbalanceadas, centrándose en los ejemplos más difíciles de clasificar.
#
# - **Fórmula**:
#   \[
#   \text{Loss} = - \alpha (1 - p_t)^\gamma \log(p_t)
#   \]
#   donde:
#   - \( p_t \) es la probabilidad predicha para la clase correcta,
#   - \( \alpha \) y \( \gamma \) son hiperparámetros para ajustar el enfoque en ejemplos difíciles.
#
# - **Funcionamiento**:
#   - Otorga mayor peso a ejemplos mal clasificados, reduciendo la pérdida en ejemplos bien clasificados.
#   - Útil cuando hay desbalance en las clases.
#
# ---
#
# ## Comparación de las Funciones de Pérdida
#
# | **Función de Pérdida**   | **Ventajas**                               | **Desventajas**                              |
# |--------------------------|--------------------------------------------|----------------------------------------------|
# | **Contrastive Loss**      | Favorece la cercanía de muestras similares y la lejanía de las disímiles. | Requiere pares etiquetados.                  |
# | **Triplet Loss**          | Fomenta un espacio de embeddings mejor estructurado. | Necesita generar tripletas, lo que puede ser complejo. |
# | **Binary Crossentropy**   | Fácil de implementar, adecuada para clasificación binaria. | No captura bien la relación entre pares.     |
# | **Hinge Loss**            | Adecuada para problemas marginados.         | Menos intuitiva en redes siamesas.           |
# | **Focal Loss**            | Excelente para problemas de clases desbalanceadas. | Más compleja de ajustar (hiperparámetros).   |
#
# ---
#
# ## Mejor Función de Pérdida para Redes Siamesas que Comparan Rostros
#
# Para una red siamesa que clasifica si dos rostros son el mismo, las funciones **Contrastive Loss** y **Triplet Loss** son las más recomendadas:
#
# 1. **Contrastive Loss** es ideal cuando se tienen pares de datos etiquetados y se busca que el modelo aprenda a diferenciar entre pares similares y disímiles de manera directa.
#
# 2. **Triplet Loss** es efectiva cuando se dispone de un gran conjunto de imágenes y es posible generar tripletas. Permite un mejor ajuste del espacio de embeddings, pero es más costosa en términos de preparación de datos.
#
# **Conclusión**: Si tienes buenos datos emparejados, **Contrastive Loss** es la mejor opción. Si puedes generar tripletas eficientemente, **Triplet Loss** puede proporcionar mejores resultados, pero con mayor complejidad.

# %%
def contrastive_loss(y_true, y_pred, margin=1.0):
    d = tf.sqrt(tf.reduce_sum(tf.square(y_pred), axis=1) + tf.keras.backend.epsilon())
    
    # Calcular la pérdida de Contrastive
    loss = tf.reduce_mean((1 - y_true) * tf.square(tf.maximum(0., margin - d)) + 
                          y_true * tf.square(d))
    
    return loss

# Initialize Adam optimizer with a learning rate of 0.0001
adam_optimizer = tf.keras.optimizers.Adam(1e-4)

checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
model_checkpoint = tf.train.Checkpoint(opt=adam_optimizer, siamese_model=siamese_model)

# %%
def training_step(batch):
    with tf.GradientTape() as tape:
        input_images, true_labels = batch
        
        # Cast true_labels to float32
        true_labels = tf.cast(true_labels, tf.float32)
        
        predicted_labels = siamese_model(input_images, training=True)
        
        # Cast predicted_labels to float32 if necessary
        predicted_labels = tf.cast(predicted_labels, tf.float32)

        # Calculate the contrastive loss
        loss_value = contrastive_loss(true_labels, predicted_labels)
        tf.print("Loss:", loss_value)
    
    gradients = tape.gradient(loss_value, siamese_model.trainable_variables)
    adam_optimizer.apply_gradients(zip(gradients, siamese_model.trainable_variables))
    
    return loss_value

# %%
def train_model(training_data, num_epochs):
    # Crear objetos de métricas para la evaluación
    recall_metric = Recall()
    precision_metric = Precision()
    
    # Bucle a través de cada época
    for current_epoch in range(1, num_epochs + 1):
        print('\nÉpoca {}/{}'.format(current_epoch, num_epochs))
        progress_bar = tf.keras.utils.Progbar(len(training_data))
        
        # Restablecer las métricas al inicio de cada época
        recall_metric.reset_state()
        precision_metric.reset_state()

        # Bucle a través de cada lote en los datos de entrenamiento
        for batch_index, current_batch in enumerate(training_data):
            # Ejecutar el paso de entrenamiento para el lote actual

            images,labels = current_batch

            loss_value = training_step(current_batch)

            # Realizar predicciones usando el modelo Siamés
            predicted_labels = siamese_model.predict(images)

            # Actualizar las métricas de recall y precisión
            recall_metric.update_state(labels, predicted_labels)
            precision_metric.update_state(labels, predicted_labels) 
            
            # Actualizar la barra de progreso
            progress_bar.update(batch_index + 1, values=[("pérdida", loss_value.numpy())])
        
        # Imprimir la pérdida, recall y precisión para la época actual
        print("Pérdida: {:.4f}, Recall: {:.4f}, Precisión: {:.4f}".format(
            loss_value.numpy(),
            recall_metric.result().numpy(),
            precision_metric.result().numpy()
        ))
        
        # Guardar puntos de control cada 10 épocas
        if current_epoch % 10 == 0: 
            model_checkpoint.save(file_prefix=checkpoint_prefix)

# %%
if(train_flag):
    train_model(train_data,60)
# Out:
# Época 1/60
# Loss: 0.25143683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
#   1/613 ━━━━━━━━━━━━━━━━━━━━ 31:46 3s/step - pérdida: 0.2514Loss: 0.248125687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#   2/613 ━━━━━━━━━━━━━━━━━━━━ 17:12 2s/step - pérdida: 0.2498Loss: 0.245430112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#   3/613 ━━━━━━━━━━━━━━━━━━━━ 17:03 2s/step - pérdida: 0.2483Loss: 0.240844458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#   4/613 ━━━━━━━━━━━━━━━━━━━━ 17:08 2s/step - pérdida: 0.2465Loss: 0.233176649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#   5/613 ━━━━━━━━━━━━━━━━━━━━ 17:05 2s/step - pérdida: 0.2438Loss: 0.205742881
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#   6/613 ━━━━━━━━━━━━━━━━━━━━ 17:02 2s/step - pérdida: 0.2375Loss: 0.205607951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#   7/613 ━━━━━━━━━━━━━━━━━━━━ 16:57 2s/step - pérdida: 0.2329Loss: 0.170009613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#   8/613 ━━━━━━━━━━━━━━━━━━━━ 16:53 2s/step - pérdida: 0.2250Loss: 0.140768528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#   9/613 ━━━━━━━━━━━━━━━━━━━━ 16:53 2s/step - pérdida: 0.2157Loss: 0.134223506
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#  10/613 ━━━━━━━━━━━━━━━━━━━━ 16:53 2s/step - pérdida: 0.2075Loss: 0.090072833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  11/613 ━━━━━━━━━━━━━━━━━━━━ 16:51 2s/step - pérdida: 0.1969Loss: 0.0795808882
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  12/613 ━━━━━━━━━━━━━━━━━━━━ 16:51 2s/step - pérdida: 0.1871Loss: 0.0680250078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#  13/613 ━━━━━━━━━━━━━━━━━━━━ 16:54 2s/step - pérdida: 0.1779Loss: 0.0923402607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  14/613 ━━━━━━━━━━━━━━━━━━━━ 16:56 2s/step - pérdida: 0.1718Loss: 0.0644551
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  15/613 ━━━━━━━━━━━━━━━━━━━━ 16:57 2s/step - pérdida: 0.1647Loss: 0.0414887667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  16/613 ━━━━━━━━━━━━━━━━━━━━ 16:57 2s/step - pérdida: 0.1570Loss: 0.0513658114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  17/613 ━━━━━━━━━━━━━━━━━━━━ 16:56 2s/step - pérdida: 0.1507Loss: 0.0293162204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  18/613 ━━━━━━━━━━━━━━━━━━━━ 16:55 2s/step - pérdida: 0.1440Loss: 0.136096641
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  19/613 ━━━━━━━━━━━━━━━━━━━━ 16:55 2s/step - pérdida: 0.1436Loss: 0.0103241596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  20/613 ━━━━━━━━━━━━━━━━━━━━ 16:54 2s/step - pérdida: 0.1369Loss: 0.045125287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  21/613 ━━━━━━━━━━━━━━━━━━━━ 16:51 2s/step - pérdida: 0.1326Loss: 0.0209726356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  22/613 ━━━━━━━━━━━━━━━━━━━━ 16:50 2s/step - pérdida: 0.1275
# Loss: 0.0181673244
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  23/613 ━━━━━━━━━━━━━━━━━━━━ 16:52 2s/step - pérdida: 0.1227Loss: 0.00742807612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  24/613 ━━━━━━━━━━━━━━━━━━━━ 16:51 2s/step - pérdida: 0.1179Loss: 0.0220012143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  25/613 ━━━━━━━━━━━━━━━━━━━━ 16:49 2s/step - pérdida: 0.1141Loss: 0.0655438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  26/613 ━━━━━━━━━━━━━━━━━━━━ 16:48 2s/step - pérdida: 0.1122Loss: 0.137747511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  27/613 ━━━━━━━━━━━━━━━━━━━━ 16:45 2s/step - pérdida: 0.1132Loss: 0.00610440318
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  28/613 ━━━━━━━━━━━━━━━━━━━━ 16:43 2s/step - pérdida: 0.1093Loss: 0.129993647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
#  29/613 ━━━━━━━━━━━━━━━━━━━━ 16:42 2s/step - pérdida: 0.1101Loss: 0.0666804537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  30/613 ━━━━━━━━━━━━━━━━━━━━ 16:40 2s/step - pérdida: 0.1086Loss: 0.0518520921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
#  31/613 ━━━━━━━━━━━━━━━━━━━━ 16:38 2s/step - pérdida: 0.1068Loss: 0.0128187742
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  32/613 ━━━━━━━━━━━━━━━━━━━━ 16:34 2s/step - pérdida: 0.1038Loss: 0.067722708
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  33/613 ━━━━━━━━━━━━━━━━━━━━ 16:32 2s/step - pérdida: 0.1027Loss: 0.135142401
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  34/613 ━━━━━━━━━━━━━━━━━━━━ 16:28 2s/step - pérdida: 0.1037Loss: 0.138978943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  35/613 ━━━━━━━━━━━━━━━━━━━━ 16:26 2s/step - pérdida: 0.1047Loss: 0.11161913
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  36/613 ━━━━━━━━━━━━━━━━━━━━ 16:24 2s/step - pérdida: 0.1049Loss: 0.0838527828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  37/613 ━━━━━━━━━━━━━━━━━━━━ 16:22 2s/step - pérdida: 0.1043Loss: 0.0633955076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#  38/613 ━━━━━━━━━━━━━━━━━━━━ 16:20 2s/step - pérdida: 0.1033Loss: 0.126308709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  39/613 ━━━━━━━━━━━━━━━━━━━━ 16:19 2s/step - pérdida: 0.1038Loss: 0.125283331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
#  40/613 ━━━━━━━━━━━━━━━━━━━━ 16:18 2s/step - pérdida: 0.1044Loss: 0.140456527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  41/613 ━━━━━━━━━━━━━━━━━━━━ 16:16 2s/step - pérdida: 0.1053Loss: 0.183913097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#  42/613 ━━━━━━━━━━━━━━━━━━━━ 16:15 2s/step - pérdida: 0.1071Loss: 0.012682396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  43/613 ━━━━━━━━━━━━━━━━━━━━ 16:14 2s/step - pérdida: 0.1049Loss: 0.129774749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  44/613 ━━━━━━━━━━━━━━━━━━━━ 16:12 2s/step - pérdida: 0.1055Loss: 0.00388582097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  45/613 ━━━━━━━━━━━━━━━━━━━━ 16:11 2s/step - pérdida: 0.1032Loss: 0.000124559039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#  46/613 ━━━━━━━━━━━━━━━━━━━━ 16:09 2s/step - pérdida: 0.1010Loss: 0.00153912441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  47/613 ━━━━━━━━━━━━━━━━━━━━ 16:07 2s/step - pérdida: 0.0989Loss: 0.125383601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#  48/613 ━━━━━━━━━━━━━━━━━━━━ 16:06 2s/step - pérdida: 0.0994Loss: 0.308186173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  49/613 ━━━━━━━━━━━━━━━━━━━━ 16:05 2s/step - pérdida: 0.1037Loss: 0.246447772
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  50/613 ━━━━━━━━━━━━━━━━━━━━ 16:04 2s/step - pérdida: 0.1066Loss: 0.012285145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  51/613 ━━━━━━━━━━━━━━━━━━━━ 16:02 2s/step - pérdida: 0.1047Loss: 0.123896316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  52/613 ━━━━━━━━━━━━━━━━━━━━ 16:01 2s/step - pérdida: 0.1051Loss: 0.127113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
#  53/613 ━━━━━━━━━━━━━━━━━━━━ 15:59 2s/step - pérdida: 0.1055Loss: 0.0813306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  54/613 ━━━━━━━━━━━━━━━━━━━━ 15:57 2s/step - pérdida: 0.1050Loss: 0.132451355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  55/613 ━━━━━━━━━━━━━━━━━━━━ 15:56 2s/step - pérdida: 0.1055Loss: 0.000876426755
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  56/613 ━━━━━━━━━━━━━━━━━━━━ 15:54 2s/step - pérdida: 0.1037Loss: 0.162458122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  57/613 ━━━━━━━━━━━━━━━━━━━━ 15:52 2s/step - pérdida: 0.1047Loss: 0.124750689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  58/613 ━━━━━━━━━━━━━━━━━━━━ 15:50 2s/step - pérdida: 0.1050Loss: 0.187497854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  59/613 ━━━━━━━━━━━━━━━━━━━━ 15:49 2s/step - pérdida: 0.1064Loss: 0.016947737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  60/613 ━━━━━━━━━━━━━━━━━━━━ 15:47 2s/step - pérdida: 0.1050Loss: 0.0745332837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  61/613 ━━━━━━━━━━━━━━━━━━━━ 15:45 2s/step - pérdida: 0.1045Loss: 0.197609171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  62/613 ━━━━━━━━━━━━━━━━━━━━ 15:43 2s/step - pérdida: 0.1060Loss: 0.124656841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#  63/613 ━━━━━━━━━━━━━━━━━━━━ 15:42 2s/step - pérdida: 0.1063Loss: 0.0640988424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  64/613 ━━━━━━━━━━━━━━━━━━━━ 15:40 2s/step - pérdida: 0.1056Loss: 0.314602077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#  65/613 ━━━━━━━━━━━━━━━━━━━━ 15:38 2s/step - pérdida: 0.1088Loss: 0.0669830218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  66/613 ━━━━━━━━━━━━━━━━━━━━ 15:37 2s/step - pérdida: 0.1082Loss: 0.117506035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  67/613 ━━━━━━━━━━━━━━━━━━━━ 15:35 2s/step - pérdida: 0.1083Loss: 0.23532249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  68/613 ━━━━━━━━━━━━━━━━━━━━ 15:33 2s/step - pérdida: 0.1102Loss: 0.0569827892
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
#  69/613 ━━━━━━━━━━━━━━━━━━━━ 15:32 2s/step - pérdida: 0.1094Loss: 0.135299057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
#  70/613 ━━━━━━━━━━━━━━━━━━━━ 15:30 2s/step - pérdida: 0.1098Loss: 0.162592828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  71/613 ━━━━━━━━━━━━━━━━━━━━ 15:29 2s/step - pérdida: 0.1105Loss: 0.184125394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  72/613 ━━━━━━━━━━━━━━━━━━━━ 15:27 2s/step - pérdida: 0.1115Loss: 0.059824612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#  73/613 ━━━━━━━━━━━━━━━━━━━━ 15:25 2s/step - pérdida: 0.1108Loss: 0.0636681691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  74/613 ━━━━━━━━━━━━━━━━━━━━ 15:24 2s/step - pérdida: 0.1102Loss: 0.125579268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  75/613 ━━━━━━━━━━━━━━━━━━━━ 15:22 2s/step - pérdida: 0.1104Loss: 0.26987797
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#  76/613 ━━━━━━━━━━━━━━━━━━━━ 15:20 2s/step - pérdida: 0.1125Loss: 0.0507696904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  77/613 ━━━━━━━━━━━━━━━━━━━━ 15:19 2s/step - pérdida: 0.1117Loss: 0.116609827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  78/613 ━━━━━━━━━━━━━━━━━━━━ 15:17 2s/step - pérdida: 0.1118Loss: 0.161867663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
#  79/613 ━━━━━━━━━━━━━━━━━━━━ 15:15 2s/step - pérdida: 0.1124Loss: 0.320952147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  80/613 ━━━━━━━━━━━━━━━━━━━━ 15:14 2s/step - pérdida: 0.1150Loss: 0.178270698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  81/613 ━━━━━━━━━━━━━━━━━━━━ 15:12 2s/step - pérdida: 0.1158Loss: 0.072659865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
#  82/613 ━━━━━━━━━━━━━━━━━━━━ 15:11 2s/step - pérdida: 0.1153Loss: 0.178969696
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  83/613 ━━━━━━━━━━━━━━━━━━━━ 15:09 2s/step - pérdida: 0.1160Loss: 0.153148681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  84/613 ━━━━━━━━━━━━━━━━━━━━ 15:07 2s/step - pérdida: 0.1165Loss: 0.158842012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
#  85/613 ━━━━━━━━━━━━━━━━━━━━ 15:06 2s/step - pérdida: 0.1170Loss: 0.253795624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  86/613 ━━━━━━━━━━━━━━━━━━━━ 15:04 2s/step - pérdida: 0.1186Loss: 0.156268239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  87/613 ━━━━━━━━━━━━━━━━━━━━ 15:03 2s/step - pérdida: 0.1190Loss: 0.135341719
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
#  88/613 ━━━━━━━━━━━━━━━━━━━━ 15:04 2s/step - pérdida: 0.1192Loss: 0.203666836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
#  89/613 ━━━━━━━━━━━━━━━━━━━━ 15:02 2s/step - pérdida: 0.1201Loss: 0.126298428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  90/613 ━━━━━━━━━━━━━━━━━━━━ 15:01 2s/step - pérdida: 0.1202Loss: 0.185473114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  91/613 ━━━━━━━━━━━━━━━━━━━━ 14:59 2s/step - pérdida: 0.1209Loss: 0.141051441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
#  92/613 ━━━━━━━━━━━━━━━━━━━━ 14:58 2s/step - pérdida: 0.1211Loss: 0.146957159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
#  93/613 ━━━━━━━━━━━━━━━━━━━━ 14:56 2s/step - pérdida: 0.1214Loss: 0.0963929594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
#  94/613 ━━━━━━━━━━━━━━━━━━━━ 14:54 2s/step - pérdida: 0.1211Loss: 0.207027629
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  95/613 ━━━━━━━━━━━━━━━━━━━━ 14:53 2s/step - pérdida: 0.1221Loss: 0.253410369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  96/613 ━━━━━━━━━━━━━━━━━━━━ 14:51 2s/step - pérdida: 0.1234Loss: 0.10048005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
#  97/613 ━━━━━━━━━━━━━━━━━━━━ 14:49 2s/step - pérdida: 0.1232Loss: 0.131339118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
#  98/613 ━━━━━━━━━━━━━━━━━━━━ 14:48 2s/step - pérdida: 0.1233Loss: 0.139959127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#  99/613 ━━━━━━━━━━━━━━━━━━━━ 14:46 2s/step - pérdida: 0.1234Loss: 0.217951208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 100/613 ━━━━━━━━━━━━━━━━━━━━ 14:44 2s/step - pérdida: 0.1244Loss: 0.232254878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 101/613 ━━━━━━━━━━━━━━━━━━━━ 14:43 2s/step - pérdida: 0.1254Loss: 0.191832453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 102/613 ━━━━━━━━━━━━━━━━━━━━ 14:41 2s/step - pérdida: 0.1261Loss: 0.230773896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 103/613 ━━━━━━━━━━━━━━━━━━━━ 14:39 2s/step - pérdida: 0.1271Loss: 0.161401331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 104/613 ━━━━━━━━━━━━━━━━━━━━ 14:37 2s/step - pérdida: 0.1274Loss: 0.167511865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 105/613 ━━━━━━━━━━━━━━━━━━━━ 14:35 2s/step - pérdida: 0.1278Loss: 0.103019282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 106/613 ━━━━━━━━━━━━━━━━━━━━ 14:34 2s/step - pérdida: 0.1276Loss: 0.0735902935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 107/613 ━━━━━━━━━━━━━━━━━━━━ 14:32 2s/step - pérdida: 0.1271Loss: 0.0928457826
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 108/613 ━━━━━━━━━━━━━━━━━━━━ 14:30 2s/step - pérdida: 0.1268Loss: 0.168240815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 109/613 ━━━━━━━━━━━━━━━━━━━━ 14:28 2s/step - pérdida: 0.1272Loss: 0.104894504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 110/613 ━━━━━━━━━━━━━━━━━━━━ 14:27 2s/step - pérdida: 0.1269Loss: 0.318656623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 111/613 ━━━━━━━━━━━━━━━━━━━━ 14:25 2s/step - pérdida: 0.1287Loss: 0.164875299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 112/613 ━━━━━━━━━━━━━━━━━━━━ 14:23 2s/step - pérdida: 0.1290Loss: 0.139373064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 113/613 ━━━━━━━━━━━━━━━━━━━━ 14:22 2s/step - pérdida: 0.1291Loss: 0.168303967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 114/613 ━━━━━━━━━━━━━━━━━━━━ 14:20 2s/step - pérdida: 0.1294Loss: 0.264249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 115/613 ━━━━━━━━━━━━━━━━━━━━ 14:18 2s/step - pérdida: 0.1306Loss: 0.277599692
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 116/613 ━━━━━━━━━━━━━━━━━━━━ 14:16 2s/step - pérdida: 0.1319Loss: 0.12601687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 117/613 ━━━━━━━━━━━━━━━━━━━━ 14:15 2s/step - pérdida: 0.1318Loss: 0.300341964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 118/613 ━━━━━━━━━━━━━━━━━━━━ 14:13 2s/step - pérdida: 0.1333Loss: 0.177654624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 119/613 ━━━━━━━━━━━━━━━━━━━━ 14:11 2s/step - pérdida: 0.1336Loss: 0.301289737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 120/613 ━━━━━━━━━━━━━━━━━━━━ 14:10 2s/step - pérdida: 0.1350Loss: 0.158250496
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 121/613 ━━━━━━━━━━━━━━━━━━━━ 14:08 2s/step - pérdida: 0.1352Loss: 0.269027919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 122/613 ━━━━━━━━━━━━━━━━━━━━ 14:06 2s/step - pérdida: 0.1363Loss: 0.210407734
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 123/613 ━━━━━━━━━━━━━━━━━━━━ 14:05 2s/step - pérdida: 0.1369Loss: 0.208433598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 124/613 ━━━━━━━━━━━━━━━━━━━━ 14:03 2s/step - pérdida: 0.1375Loss: 0.194895983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 125/613 ━━━━━━━━━━━━━━━━━━━━ 14:01 2s/step - pérdida: 0.1379Loss: 0.213378012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 126/613 ━━━━━━━━━━━━━━━━━━━━ 14:00 2s/step - pérdida: 0.1385Loss: 0.296512783
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 127/613 ━━━━━━━━━━━━━━━━━━━━ 13:58 2s/step - pérdida: 0.1398Loss: 0.169644296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 128/613 ━━━━━━━━━━━━━━━━━━━━ 13:56 2s/step - pérdida: 0.1400Loss: 0.250204951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 129/613 ━━━━━━━━━━━━━━━━━━━━ 13:54 2s/step - pérdida: 0.1409Loss: 0.229716465
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 130/613 ━━━━━━━━━━━━━━━━━━━━ 13:53 2s/step - pérdida: 0.1416Loss: 0.231403679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 131/613 ━━━━━━━━━━━━━━━━━━━━ 13:51 2s/step - pérdida: 0.1422Loss: 0.204249173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 132/613 ━━━━━━━━━━━━━━━━━━━━ 13:49 2s/step - pérdida: 0.1427Loss: 0.148038775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 133/613 ━━━━━━━━━━━━━━━━━━━━ 13:48 2s/step - pérdida: 0.1428Loss: 0.122546196
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 134/613 ━━━━━━━━━━━━━━━━━━━━ 13:46 2s/step - pérdida: 0.1426Loss: 0.210532621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 135/613 ━━━━━━━━━━━━━━━━━━━━ 13:45 2s/step - pérdida: 0.1431Loss: 0.200141311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 136/613 ━━━━━━━━━━━━━━━━━━━━ 13:43 2s/step - pérdida: 0.1435Loss: 0.234230056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 137/613 ━━━━━━━━━━━━━━━━━━━━ 13:41 2s/step - pérdida: 0.1442Loss: 0.151748866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 138/613 ━━━━━━━━━━━━━━━━━━━━ 13:39 2s/step - pérdida: 0.1442Loss: 0.270467073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 139/613 ━━━━━━━━━━━━━━━━━━━━ 13:38 2s/step - pérdida: 0.1452Loss: 0.192238241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 140/613 ━━━━━━━━━━━━━━━━━━━━ 13:36 2s/step - pérdida: 0.1455Loss: 0.197924256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 141/613 ━━━━━━━━━━━━━━━━━━━━ 13:34 2s/step - pérdida: 0.1459Loss: 0.249147937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 142/613 ━━━━━━━━━━━━━━━━━━━━ 13:32 2s/step - pérdida: 0.1466Loss: 0.207080588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 143/613 ━━━━━━━━━━━━━━━━━━━━ 13:31 2s/step - pérdida: 0.1470Loss: 0.133927822
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 144/613 ━━━━━━━━━━━━━━━━━━━━ 13:29 2s/step - pérdida: 0.1469Loss: 0.305064321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 145/613 ━━━━━━━━━━━━━━━━━━━━ 13:27 2s/step - pérdida: 0.1480Loss: 0.232285544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 146/613 ━━━━━━━━━━━━━━━━━━━━ 13:26 2s/step - pérdida: 0.1486Loss: 0.117078006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 147/613 ━━━━━━━━━━━━━━━━━━━━ 13:24 2s/step - pérdida: 0.1484Loss: 0.191899419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 148/613 ━━━━━━━━━━━━━━━━━━━━ 13:22 2s/step - pérdida: 0.1487Loss: 0.282066941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 149/613 ━━━━━━━━━━━━━━━━━━━━ 13:20 2s/step - pérdida: 0.1496Loss: 0.302650452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 150/613 ━━━━━━━━━━━━━━━━━━━━ 13:19 2s/step - pérdida: 0.1506Loss: 0.179315925
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 151/613 ━━━━━━━━━━━━━━━━━━━━ 13:17 2s/step - pérdida: 0.1508Loss: 0.276802659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 152/613 ━━━━━━━━━━━━━━━━━━━━ 13:15 2s/step - pérdida: 0.1516Loss: 0.211255819
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 153/613 ━━━━━━━━━━━━━━━━━━━━ 13:14 2s/step - pérdida: 0.1520Loss: 0.152485207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 154/613 ━━━━━━━━━━━━━━━━━━━━ 13:12 2s/step - pérdida: 0.1520Loss: 0.250391781
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 155/613 ━━━━━━━━━━━━━━━━━━━━ 13:10 2s/step - pérdida: 0.1526Loss: 0.275426894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 156/613 ━━━━━━━━━━━━━━━━━━━━ 13:09 2s/step - pérdida: 0.1534Loss: 0.265766323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 157/613 ━━━━━━━━━━━━━━━━━━━━ 13:07 2s/step - pérdida: 0.1541Loss: 0.219476908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 158/613 ━━━━━━━━━━━━━━━━━━━━ 13:05 2s/step - pérdida: 0.1545Loss: 0.198931932
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 159/613 ━━━━━━━━━━━━━━━━━━━━ 13:03 2s/step - pérdida: 0.1548Loss: 0.233882874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 160/613 ━━━━━━━━━━━━━━━━━━━━ 13:02 2s/step - pérdida: 0.1553Loss: 0.214080036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 161/613 ━━━━━━━━━━━━━━━━━━━━ 13:00 2s/step - pérdida: 0.1557Loss: 0.225951985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 162/613 ━━━━━━━━━━━━━━━━━━━━ 12:58 2s/step - pérdida: 0.1561Loss: 0.214041144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 163/613 ━━━━━━━━━━━━━━━━━━━━ 12:56 2s/step - pérdida: 0.1565Loss: 0.210673064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 164/613 ━━━━━━━━━━━━━━━━━━━━ 12:55 2s/step - pérdida: 0.1568Loss: 0.267937452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 165/613 ━━━━━━━━━━━━━━━━━━━━ 12:53 2s/step - pérdida: 0.1575Loss: 0.183157936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 166/613 ━━━━━━━━━━━━━━━━━━━━ 12:51 2s/step - pérdida: 0.1576Loss: 0.209451348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 167/613 ━━━━━━━━━━━━━━━━━━━━ 12:50 2s/step - pérdida: 0.1579Loss: 0.222244799
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 168/613 ━━━━━━━━━━━━━━━━━━━━ 12:48 2s/step - pérdida: 0.1583Loss: 0.206948683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 169/613 ━━━━━━━━━━━━━━━━━━━━ 12:46 2s/step - pérdida: 0.1586Loss: 0.169993043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 170/613 ━━━━━━━━━━━━━━━━━━━━ 12:44 2s/step - pérdida: 0.1587Loss: 0.193550959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 171/613 ━━━━━━━━━━━━━━━━━━━━ 12:43 2s/step - pérdida: 0.1589Loss: 0.175385296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 172/613 ━━━━━━━━━━━━━━━━━━━━ 12:41 2s/step - pérdida: 0.1590Loss: 0.201127842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 173/613 ━━━━━━━━━━━━━━━━━━━━ 12:39 2s/step - pérdida: 0.1592Loss: 0.313853025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 174/613 ━━━━━━━━━━━━━━━━━━━━ 12:38 2s/step - pérdida: 0.1601Loss: 0.207148969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 175/613 ━━━━━━━━━━━━━━━━━━━━ 12:36 2s/step - pérdida: 0.1604Loss: 0.291993201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 176/613 ━━━━━━━━━━━━━━━━━━━━ 12:34 2s/step - pérdida: 0.1611Loss: 0.347957134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 177/613 ━━━━━━━━━━━━━━━━━━━━ 12:32 2s/step - pérdida: 0.1622Loss: 0.181675732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 178/613 ━━━━━━━━━━━━━━━━━━━━ 12:31 2s/step - pérdida: 0.1623Loss: 0.236329675
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 179/613 ━━━━━━━━━━━━━━━━━━━━ 12:29 2s/step - pérdida: 0.1627Loss: 0.293444872
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 180/613 ━━━━━━━━━━━━━━━━━━━━ 12:27 2s/step - pérdida: 0.1634Loss: 0.229901657
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 181/613 ━━━━━━━━━━━━━━━━━━━━ 12:25 2s/step - pérdida: 0.1638Loss: 0.252589107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 182/613 ━━━━━━━━━━━━━━━━━━━━ 12:24 2s/step - pérdida: 0.1643Loss: 0.167885169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 183/613 ━━━━━━━━━━━━━━━━━━━━ 12:22 2s/step - pérdida: 0.1643Loss: 0.294441879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 184/613 ━━━━━━━━━━━━━━━━━━━━ 12:20 2s/step - pérdida: 0.1650Loss: 0.194102898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 185/613 ━━━━━━━━━━━━━━━━━━━━ 12:19 2s/step - pérdida: 0.1652Loss: 0.262455195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 186/613 ━━━━━━━━━━━━━━━━━━━━ 12:17 2s/step - pérdida: 0.1657Loss: 0.231827483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 187/613 ━━━━━━━━━━━━━━━━━━━━ 12:15 2s/step - pérdida: 0.1661Loss: 0.211523563
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 188/613 ━━━━━━━━━━━━━━━━━━━━ 12:13 2s/step - pérdida: 0.1663Loss: 0.248658016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 189/613 ━━━━━━━━━━━━━━━━━━━━ 12:12 2s/step - pérdida: 0.1667Loss: 0.302393228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 190/613 ━━━━━━━━━━━━━━━━━━━━ 12:10 2s/step - pérdida: 0.1674Loss: 0.20941779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 191/613 ━━━━━━━━━━━━━━━━━━━━ 12:08 2s/step - pérdida: 0.1677Loss: 0.213313922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 192/613 ━━━━━━━━━━━━━━━━━━━━ 12:06 2s/step - pérdida: 0.1679Loss: 0.285555333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 193/613 ━━━━━━━━━━━━━━━━━━━━ 12:05 2s/step - pérdida: 0.1685Loss: 0.232939988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 194/613 ━━━━━━━━━━━━━━━━━━━━ 12:03 2s/step - pérdida: 0.1688Loss: 0.276140809
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 195/613 ━━━━━━━━━━━━━━━━━━━━ 12:01 2s/step - pérdida: 0.1694Loss: 0.235032275
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 196/613 ━━━━━━━━━━━━━━━━━━━━ 11:59 2s/step - pérdida: 0.1697Loss: 0.285967946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 197/613 ━━━━━━━━━━━━━━━━━━━━ 11:58 2s/step - pérdida: 0.1703Loss: 0.255988181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 198/613 ━━━━━━━━━━━━━━━━━━━━ 11:56 2s/step - pérdida: 0.1708Loss: 0.220852688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 199/613 ━━━━━━━━━━━━━━━━━━━━ 11:54 2s/step - pérdida: 0.1710Loss: 0.220365793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 200/613 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - pérdida: 0.1712Loss: 0.22347489
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 201/613 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - pérdida: 0.1715Loss: 0.237561092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 202/613 ━━━━━━━━━━━━━━━━━━━━ 11:49 2s/step - pérdida: 0.1718Loss: 0.209227219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 203/613 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - pérdida: 0.1720Loss: 0.245214328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 204/613 ━━━━━━━━━━━━━━━━━━━━ 11:46 2s/step - pérdida: 0.1724Loss: 0.185223952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 205/613 ━━━━━━━━━━━━━━━━━━━━ 11:44 2s/step - pérdida: 0.1724Loss: 0.24761197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 206/613 ━━━━━━━━━━━━━━━━━━━━ 11:42 2s/step - pérdida: 0.1728Loss: 0.262941897
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 207/613 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - pérdida: 0.1732Loss: 0.202832624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 208/613 ━━━━━━━━━━━━━━━━━━━━ 11:39 2s/step - pérdida: 0.1734Loss: 0.285118937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 209/613 ━━━━━━━━━━━━━━━━━━━━ 11:37 2s/step - pérdida: 0.1739Loss: 0.279885948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 210/613 ━━━━━━━━━━━━━━━━━━━━ 11:35 2s/step - pérdida: 0.1744Loss: 0.273779631
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 211/613 ━━━━━━━━━━━━━━━━━━━━ 11:34 2s/step - pérdida: 0.1749Loss: 0.27518639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 212/613 ━━━━━━━━━━━━━━━━━━━━ 11:32 2s/step - pérdida: 0.1754Loss: 0.232402191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 213/613 ━━━━━━━━━━━━━━━━━━━━ 11:30 2s/step - pérdida: 0.1756Loss: 0.237401843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 214/613 ━━━━━━━━━━━━━━━━━━━━ 11:28 2s/step - pérdida: 0.1759Loss: 0.233803451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 215/613 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - pérdida: 0.1762Loss: 0.225215554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 216/613 ━━━━━━━━━━━━━━━━━━━━ 11:25 2s/step - pérdida: 0.1764Loss: 0.240967065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 217/613 ━━━━━━━━━━━━━━━━━━━━ 11:23 2s/step - pérdida: 0.1767Loss: 0.221921861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 218/613 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - pérdida: 0.1769Loss: 0.280790597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 219/613 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - pérdida: 0.1774Loss: 0.259123325
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 220/613 ━━━━━━━━━━━━━━━━━━━━ 11:18 2s/step - pérdida: 0.1778Loss: 0.234451503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 221/613 ━━━━━━━━━━━━━━━━━━━━ 11:16 2s/step - pérdida: 0.1780Loss: 0.235350728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 222/613 ━━━━━━━━━━━━━━━━━━━━ 11:15 2s/step - pérdida: 0.1783Loss: 0.240772456
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 223/613 ━━━━━━━━━━━━━━━━━━━━ 11:13 2s/step - pérdida: 0.1786Loss: 0.227508575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 224/613 ━━━━━━━━━━━━━━━━━━━━ 11:11 2s/step - pérdida: 0.1788Loss: 0.246657968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 225/613 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - pérdida: 0.1791Loss: 0.226565585
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 226/613 ━━━━━━━━━━━━━━━━━━━━ 11:08 2s/step - pérdida: 0.1793Loss: 0.23045522
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 227/613 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - pérdida: 0.1795Loss: 0.260652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 228/613 ━━━━━━━━━━━━━━━━━━━━ 11:04 2s/step - pérdida: 0.1799Loss: 0.260496914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 229/613 ━━━━━━━━━━━━━━━━━━━━ 11:02 2s/step - pérdida: 0.1802Loss: 0.25581497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 230/613 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - pérdida: 0.1806Loss: 0.231131509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 231/613 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - pérdida: 0.1808Loss: 0.235406056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 232/613 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - pérdida: 0.1810Loss: 0.284765065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 233/613 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - pérdida: 0.1815Loss: 0.241384432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 234/613 ━━━━━━━━━━━━━━━━━━━━ 10:54 2s/step - pérdida: 0.1817Loss: 0.2534931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 235/613 ━━━━━━━━━━━━━━━━━━━━ 10:52 2s/step - pérdida: 0.1820Loss: 0.253115594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 236/613 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - pérdida: 0.1823Loss: 0.27000007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 237/613 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - pérdida: 0.1827Loss: 0.260394394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 238/613 ━━━━━━━━━━━━━━━━━━━━ 10:47 2s/step - pérdida: 0.1830Loss: 0.237935841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 239/613 ━━━━━━━━━━━━━━━━━━━━ 10:45 2s/step - pérdida: 0.1832Loss: 0.224654526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 240/613 ━━━━━━━━━━━━━━━━━━━━ 10:43 2s/step - pérdida: 0.1834Loss: 0.255551279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 241/613 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - pérdida: 0.1837Loss: 0.224620521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 242/613 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - pérdida: 0.1839Loss: 0.224173158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 243/613 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - pérdida: 0.1841Loss: 0.287095487
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 244/613 ━━━━━━━━━━━━━━━━━━━━ 10:36 2s/step - pérdida: 0.1845Loss: 0.255038679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 245/613 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - pérdida: 0.1848Loss: 0.232071549
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 246/613 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - pérdida: 0.1850Loss: 0.20995754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 247/613 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - pérdida: 0.1851Loss: 0.250727385
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 248/613 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - pérdida: 0.1853Loss: 0.2125974
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 249/613 ━━━━━━━━━━━━━━━━━━━━ 10:28 2s/step - pérdida: 0.1854Loss: 0.246402591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 250/613 ━━━━━━━━━━━━━━━━━━━━ 10:26 2s/step - pérdida: 0.1857Loss: 0.221090674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 251/613 ━━━━━━━━━━━━━━━━━━━━ 10:24 2s/step - pérdida: 0.1858Loss: 0.271163344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 252/613 ━━━━━━━━━━━━━━━━━━━━ 10:23 2s/step - pérdida: 0.1862Loss: 0.273090124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 253/613 ━━━━━━━━━━━━━━━━━━━━ 10:21 2s/step - pérdida: 0.1865Loss: 0.244320452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 254/613 ━━━━━━━━━━━━━━━━━━━━ 10:19 2s/step - pérdida: 0.1867Loss: 0.211318761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 255/613 ━━━━━━━━━━━━━━━━━━━━ 10:17 2s/step - pérdida: 0.1868Loss: 0.243089691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 256/613 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - pérdida: 0.1870Loss: 0.274380922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 257/613 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - pérdida: 0.1874Loss: 0.256060839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 258/613 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - pérdida: 0.1876Loss: 0.218623698
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 259/613 ━━━━━━━━━━━━━━━━━━━━ 10:10 2s/step - pérdida: 0.1878Loss: 0.239237964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 260/613 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - pérdida: 0.1880Loss: 0.256339073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 261/613 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - pérdida: 0.1882Loss: 0.226427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 262/613 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - pérdida: 0.1884Loss: 0.236309588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 263/613 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - pérdida: 0.1886Loss: 0.267411083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 264/613 ━━━━━━━━━━━━━━━━━━━━ 10:02 2s/step - pérdida: 0.1889Loss: 0.257263571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 265/613 ━━━━━━━━━━━━━━━━━━━━ 10:00 2s/step - pérdida: 0.1891Loss: 0.24462992
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 266/613 ━━━━━━━━━━━━━━━━━━━━ 9:58 2s/step - pérdida: 0.1893 Loss: 0.276995778
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 267/613 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - pérdida: 0.1897Loss: 0.224560216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 268/613 ━━━━━━━━━━━━━━━━━━━━ 9:55 2s/step - pérdida: 0.1898Loss: 0.263014793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 269/613 ━━━━━━━━━━━━━━━━━━━━ 9:53 2s/step - pérdida: 0.1901Loss: 0.235050112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 270/613 ━━━━━━━━━━━━━━━━━━━━ 9:51 2s/step - pérdida: 0.1902Loss: 0.239461303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 271/613 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - pérdida: 0.1904Loss: 0.213942528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 272/613 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - pérdida: 0.1905Loss: 0.222571433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 273/613 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - pérdida: 0.1906Loss: 0.246235371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 274/613 ━━━━━━━━━━━━━━━━━━━━ 9:44 2s/step - pérdida: 0.1908Loss: 0.255629182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 275/613 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - pérdida: 0.1910Loss: 0.23402676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 276/613 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - pérdida: 0.1912Loss: 0.254006207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 277/613 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - pérdida: 0.1914Loss: 0.260834098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 278/613 ━━━━━━━━━━━━━━━━━━━━ 9:38 2s/step - pérdida: 0.1917Loss: 0.214067519
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 279/613 ━━━━━━━━━━━━━━━━━━━━ 9:36 2s/step - pérdida: 0.1918Loss: 0.268679976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 280/613 ━━━━━━━━━━━━━━━━━━━━ 9:34 2s/step - pérdida: 0.1920Loss: 0.222839877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 281/613 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - pérdida: 0.1921Loss: 0.229244426
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 282/613 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - pérdida: 0.1923Loss: 0.216836959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 283/613 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - pérdida: 0.1924Loss: 0.272809744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 284/613 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - pérdida: 0.1926Loss: 0.247899383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 285/613 ━━━━━━━━━━━━━━━━━━━━ 9:26 2s/step - pérdida: 0.1928Loss: 0.285668701
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 286/613 ━━━━━━━━━━━━━━━━━━━━ 9:24 2s/step - pérdida: 0.1932Loss: 0.290897846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 287/613 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - pérdida: 0.1935Loss: 0.257574975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 288/613 ━━━━━━━━━━━━━━━━━━━━ 9:21 2s/step - pérdida: 0.1937Loss: 0.293944269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 289/613 ━━━━━━━━━━━━━━━━━━━━ 9:19 2s/step - pérdida: 0.1941Loss: 0.24642989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 290/613 ━━━━━━━━━━━━━━━━━━━━ 9:17 2s/step - pérdida: 0.1943Loss: 0.250521541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 291/613 ━━━━━━━━━━━━━━━━━━━━ 9:15 2s/step - pérdida: 0.1944Loss: 0.254102647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 292/613 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - pérdida: 0.1946Loss: 0.22614342
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 293/613 ━━━━━━━━━━━━━━━━━━━━ 9:12 2s/step - pérdida: 0.1948Loss: 0.222870409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 294/613 ━━━━━━━━━━━━━━━━━━━━ 9:10 2s/step - pérdida: 0.1949Loss: 0.254945904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 295/613 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - pérdida: 0.1951Loss: 0.261820793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 296/613 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - pérdida: 0.1953Loss: 0.25325346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 297/613 ━━━━━━━━━━━━━━━━━━━━ 9:05 2s/step - pérdida: 0.1955Loss: 0.241782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 298/613 ━━━━━━━━━━━━━━━━━━━━ 9:03 2s/step - pérdida: 0.1956Loss: 0.2253104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 299/613 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - pérdida: 0.1957Loss: 0.235482782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 300/613 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - pérdida: 0.1959Loss: 0.246831864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 301/613 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - pérdida: 0.1960Loss: 0.242284879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 302/613 ━━━━━━━━━━━━━━━━━━━━ 8:57 2s/step - pérdida: 0.1962Loss: 0.284748614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 303/613 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - pérdida: 0.1965Loss: 0.245638639
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 304/613 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - pérdida: 0.1966Loss: 0.259290516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 305/613 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - pérdida: 0.1968Loss: 0.223969832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 306/613 ━━━━━━━━━━━━━━━━━━━━ 8:50 2s/step - pérdida: 0.1969Loss: 0.252231479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 307/613 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - pérdida: 0.1971Loss: 0.27893129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 308/613 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - pérdida: 0.1974Loss: 0.237026662
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 309/613 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - pérdida: 0.1975Loss: 0.250219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 310/613 ━━━━━━━━━━━━━━━━━━━━ 8:43 2s/step - pérdida: 0.1977Loss: 0.271440864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 311/613 ━━━━━━━━━━━━━━━━━━━━ 8:41 2s/step - pérdida: 0.1979Loss: 0.212304905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 312/613 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - pérdida: 0.1980Loss: 0.246948689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 313/613 ━━━━━━━━━━━━━━━━━━━━ 8:38 2s/step - pérdida: 0.1981Loss: 0.220978603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 314/613 ━━━━━━━━━━━━━━━━━━━━ 8:36 2s/step - pérdida: 0.1982Loss: 0.243249297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 315/613 ━━━━━━━━━━━━━━━━━━━━ 8:34 2s/step - pérdida: 0.1983Loss: 0.248175412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 316/613 ━━━━━━━━━━━━━━━━━━━━ 8:32 2s/step - pérdida: 0.1985Loss: 0.272732645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 317/613 ━━━━━━━━━━━━━━━━━━━━ 8:31 2s/step - pérdida: 0.1987Loss: 0.253830284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 318/613 ━━━━━━━━━━━━━━━━━━━━ 8:29 2s/step - pérdida: 0.1989Loss: 0.215647042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 319/613 ━━━━━━━━━━━━━━━━━━━━ 8:27 2s/step - pérdida: 0.1990Loss: 0.232292607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 320/613 ━━━━━━━━━━━━━━━━━━━━ 8:25 2s/step - pérdida: 0.1991Loss: 0.24473691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 321/613 ━━━━━━━━━━━━━━━━━━━━ 8:24 2s/step - pérdida: 0.1992Loss: 0.232298613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 322/613 ━━━━━━━━━━━━━━━━━━━━ 8:22 2s/step - pérdida: 0.1993Loss: 0.238458201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 323/613 ━━━━━━━━━━━━━━━━━━━━ 8:20 2s/step - pérdida: 0.1994Loss: 0.233621091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 324/613 ━━━━━━━━━━━━━━━━━━━━ 8:19 2s/step - pérdida: 0.1995Loss: 0.219976157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 325/613 ━━━━━━━━━━━━━━━━━━━━ 8:17 2s/step - pérdida: 0.1996Loss: 0.209515035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 326/613 ━━━━━━━━━━━━━━━━━━━━ 8:15 2s/step - pérdida: 0.1996Loss: 0.273623884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 327/613 ━━━━━━━━━━━━━━━━━━━━ 8:13 2s/step - pérdida: 0.1998Loss: 0.189410314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 328/613 ━━━━━━━━━━━━━━━━━━━━ 8:12 2s/step - pérdida: 0.1998Loss: 0.191726834
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 329/613 ━━━━━━━━━━━━━━━━━━━━ 8:10 2s/step - pérdida: 0.1998Loss: 0.264071763
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 330/613 ━━━━━━━━━━━━━━━━━━━━ 8:08 2s/step - pérdida: 0.2000Loss: 0.199460015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 331/613 ━━━━━━━━━━━━━━━━━━━━ 8:06 2s/step - pérdida: 0.2000Loss: 0.287097871
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 332/613 ━━━━━━━━━━━━━━━━━━━━ 8:05 2s/step - pérdida: 0.2002Loss: 0.209717885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 333/613 ━━━━━━━━━━━━━━━━━━━━ 8:03 2s/step - pérdida: 0.2003Loss: 0.245844603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 334/613 ━━━━━━━━━━━━━━━━━━━━ 8:01 2s/step - pérdida: 0.2004Loss: 0.26116994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 335/613 ━━━━━━━━━━━━━━━━━━━━ 8:00 2s/step - pérdida: 0.2006Loss: 0.272211909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 336/613 ━━━━━━━━━━━━━━━━━━━━ 7:58 2s/step - pérdida: 0.2008Loss: 0.235554457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 337/613 ━━━━━━━━━━━━━━━━━━━━ 7:56 2s/step - pérdida: 0.2009Loss: 0.291764319
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 338/613 ━━━━━━━━━━━━━━━━━━━━ 7:54 2s/step - pérdida: 0.2012Loss: 0.273949504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 339/613 ━━━━━━━━━━━━━━━━━━━━ 7:53 2s/step - pérdida: 0.2014Loss: 0.226647377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 340/613 ━━━━━━━━━━━━━━━━━━━━ 7:51 2s/step - pérdida: 0.2015Loss: 0.218857378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 341/613 ━━━━━━━━━━━━━━━━━━━━ 7:49 2s/step - pérdida: 0.2015Loss: 0.234158769
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 342/613 ━━━━━━━━━━━━━━━━━━━━ 7:47 2s/step - pérdida: 0.2016Loss: 0.166955024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 343/613 ━━━━━━━━━━━━━━━━━━━━ 7:46 2s/step - pérdida: 0.2015Loss: 0.224566162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 344/613 ━━━━━━━━━━━━━━━━━━━━ 7:44 2s/step - pérdida: 0.2016Loss: 0.241362721
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 345/613 ━━━━━━━━━━━━━━━━━━━━ 7:42 2s/step - pérdida: 0.2017Loss: 0.240455702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 346/613 ━━━━━━━━━━━━━━━━━━━━ 7:41 2s/step - pérdida: 0.2018Loss: 0.213961884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 347/613 ━━━━━━━━━━━━━━━━━━━━ 7:39 2s/step - pérdida: 0.2018Loss: 0.208077431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 348/613 ━━━━━━━━━━━━━━━━━━━━ 7:37 2s/step - pérdida: 0.2019Loss: 0.203063667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 349/613 ━━━━━━━━━━━━━━━━━━━━ 7:35 2s/step - pérdida: 0.2019Loss: 0.237165287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 350/613 ━━━━━━━━━━━━━━━━━━━━ 7:34 2s/step - pérdida: 0.2020Loss: 0.206557333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 351/613 ━━━━━━━━━━━━━━━━━━━━ 7:32 2s/step - pérdida: 0.2020Loss: 0.233864203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 352/613 ━━━━━━━━━━━━━━━━━━━━ 7:30 2s/step - pérdida: 0.2021Loss: 0.229872376
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 353/613 ━━━━━━━━━━━━━━━━━━━━ 7:29 2s/step - pérdida: 0.2021Loss: 0.222285941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 354/613 ━━━━━━━━━━━━━━━━━━━━ 7:27 2s/step - pérdida: 0.2022Loss: 0.230613977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 355/613 ━━━━━━━━━━━━━━━━━━━━ 7:25 2s/step - pérdida: 0.2023Loss: 0.233111441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 356/613 ━━━━━━━━━━━━━━━━━━━━ 7:23 2s/step - pérdida: 0.2024Loss: 0.292920709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 357/613 ━━━━━━━━━━━━━━━━━━━━ 7:22 2s/step - pérdida: 0.2026Loss: 0.268281132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 358/613 ━━━━━━━━━━━━━━━━━━━━ 7:20 2s/step - pérdida: 0.2028Loss: 0.255031258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 359/613 ━━━━━━━━━━━━━━━━━━━━ 7:18 2s/step - pérdida: 0.2030Loss: 0.264732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 360/613 ━━━━━━━━━━━━━━━━━━━━ 7:16 2s/step - pérdida: 0.2031Loss: 0.302975446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 361/613 ━━━━━━━━━━━━━━━━━━━━ 7:15 2s/step - pérdida: 0.2034Loss: 0.229324982
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 362/613 ━━━━━━━━━━━━━━━━━━━━ 7:13 2s/step - pérdida: 0.2035Loss: 0.23330915
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 363/613 ━━━━━━━━━━━━━━━━━━━━ 7:11 2s/step - pérdida: 0.2036Loss: 0.245128468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 364/613 ━━━━━━━━━━━━━━━━━━━━ 7:10 2s/step - pérdida: 0.2037Loss: 0.203031659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 365/613 ━━━━━━━━━━━━━━━━━━━━ 7:08 2s/step - pérdida: 0.2037Loss: 0.266498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 366/613 ━━━━━━━━━━━━━━━━━━━━ 7:06 2s/step - pérdida: 0.2038Loss: 0.23214677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 367/613 ━━━━━━━━━━━━━━━━━━━━ 7:04 2s/step - pérdida: 0.2039Loss: 0.256257564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 368/613 ━━━━━━━━━━━━━━━━━━━━ 7:03 2s/step - pérdida: 0.2041Loss: 0.236739308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 369/613 ━━━━━━━━━━━━━━━━━━━━ 7:01 2s/step - pérdida: 0.2041Loss: 0.20901382
# 1/1 ━━━━━━━━━━━━━━━━━━━━ -0s -433187us/step
# 370/613 ━━━━━━━━━━━━━━━━━━━━ 6:59 2s/step - pérdida: 0.2042Loss: 0.22160311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 371/613 ━━━━━━━━━━━━━━━━━━━━ 6:57 2s/step - pérdida: 0.2042Loss: 0.244522631
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 372/613 ━━━━━━━━━━━━━━━━━━━━ 6:55 2s/step - pérdida: 0.2043Loss: 0.232116222
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 373/613 ━━━━━━━━━━━━━━━━━━━━ 6:54 2s/step - pérdida: 0.2044Loss: 0.249595895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 374/613 ━━━━━━━━━━━━━━━━━━━━ 6:52 2s/step - pérdida: 0.2045Loss: 0.209025964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 375/613 ━━━━━━━━━━━━━━━━━━━━ 6:50 2s/step - pérdida: 0.2045Loss: 0.23625356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 376/613 ━━━━━━━━━━━━━━━━━━━━ 6:48 2s/step - pérdida: 0.2046Loss: 0.274119556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 377/613 ━━━━━━━━━━━━━━━━━━━━ 6:47 2s/step - pérdida: 0.2048Loss: 0.212220699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 378/613 ━━━━━━━━━━━━━━━━━━━━ 6:45 2s/step - pérdida: 0.2048Loss: 0.234385565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 379/613 ━━━━━━━━━━━━━━━━━━━━ 6:43 2s/step - pérdida: 0.2049Loss: 0.220623761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 380/613 ━━━━━━━━━━━━━━━━━━━━ 6:42 2s/step - pérdida: 0.2049Loss: 0.234171301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 381/613 ━━━━━━━━━━━━━━━━━━━━ 6:40 2s/step - pérdida: 0.2050Loss: 0.249527127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 382/613 ━━━━━━━━━━━━━━━━━━━━ 6:38 2s/step - pérdida: 0.2051Loss: 0.214952499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 383/613 ━━━━━━━━━━━━━━━━━━━━ 6:36 2s/step - pérdida: 0.2051Loss: 0.2124165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 384/613 ━━━━━━━━━━━━━━━━━━━━ 6:35 2s/step - pérdida: 0.2052Loss: 0.191921696
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 385/613 ━━━━━━━━━━━━━━━━━━━━ 6:33 2s/step - pérdida: 0.2051Loss: 0.234386295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 386/613 ━━━━━━━━━━━━━━━━━━━━ 6:31 2s/step - pérdida: 0.2052Loss: 0.210920781
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 387/613 ━━━━━━━━━━━━━━━━━━━━ 6:29 2s/step - pérdida: 0.2052Loss: 0.248520255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 388/613 ━━━━━━━━━━━━━━━━━━━━ 6:28 2s/step - pérdida: 0.2053Loss: 0.16742447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 389/613 ━━━━━━━━━━━━━━━━━━━━ 6:27 2s/step - pérdida: 0.2052Loss: 0.25394392
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 390/613 ━━━━━━━━━━━━━━━━━━━━ 6:25 2s/step - pérdida: 0.2054Loss: 0.238366157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 391/613 ━━━━━━━━━━━━━━━━━━━━ 6:23 2s/step - pérdida: 0.2054Loss: 0.185071379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 392/613 ━━━━━━━━━━━━━━━━━━━━ 6:21 2s/step - pérdida: 0.2054Loss: 0.264854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 393/613 ━━━━━━━━━━━━━━━━━━━━ 6:20 2s/step - pérdida: 0.2055Loss: 0.156141326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 394/613 ━━━━━━━━━━━━━━━━━━━━ 6:18 2s/step - pérdida: 0.2054Loss: 0.244719267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 395/613 ━━━━━━━━━━━━━━━━━━━━ 6:16 2s/step - pérdida: 0.2055Loss: 0.306567192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 396/613 ━━━━━━━━━━━━━━━━━━━━ 6:14 2s/step - pérdida: 0.2058Loss: 0.188948348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 397/613 ━━━━━━━━━━━━━━━━━━━━ 6:13 2s/step - pérdida: 0.2057Loss: 0.275279552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 398/613 ━━━━━━━━━━━━━━━━━━━━ 6:11 2s/step - pérdida: 0.2059Loss: 0.204179764
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 399/613 ━━━━━━━━━━━━━━━━━━━━ 6:09 2s/step - pérdida: 0.2059Loss: 0.197216555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 400/613 ━━━━━━━━━━━━━━━━━━━━ 6:07 2s/step - pérdida: 0.2059Loss: 0.130416796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 401/613 ━━━━━━━━━━━━━━━━━━━━ 6:06 2s/step - pérdida: 0.2057Loss: 0.202176422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 402/613 ━━━━━━━━━━━━━━━━━━━━ 6:04 2s/step - pérdida: 0.2057Loss: 0.243878454
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 403/613 ━━━━━━━━━━━━━━━━━━━━ 6:02 2s/step - pérdida: 0.2058Loss: 0.213108361
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 404/613 ━━━━━━━━━━━━━━━━━━━━ 6:01 2s/step - pérdida: 0.2058Loss: 0.228291154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 405/613 ━━━━━━━━━━━━━━━━━━━━ 5:59 2s/step - pérdida: 0.2059Loss: 0.212337583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 406/613 ━━━━━━━━━━━━━━━━━━━━ 5:57 2s/step - pérdida: 0.2059Loss: 0.195445523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 407/613 ━━━━━━━━━━━━━━━━━━━━ 5:55 2s/step - pérdida: 0.2058Loss: 0.18462342
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 408/613 ━━━━━━━━━━━━━━━━━━━━ 5:54 2s/step - pérdida: 0.2058Loss: 0.261007428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 409/613 ━━━━━━━━━━━━━━━━━━━━ 5:52 2s/step - pérdida: 0.2059Loss: 0.265294135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 410/613 ━━━━━━━━━━━━━━━━━━━━ 5:50 2s/step - pérdida: 0.2061Loss: 0.172930658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 411/613 ━━━━━━━━━━━━━━━━━━━━ 5:48 2s/step - pérdida: 0.2060Loss: 0.20905748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 239/613 ━━━━━━━━━━━━━━━━━━━━ 13:31 2s/step - pérdida: 0.1821Loss: 0.246481031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 240/613 ━━━━━━━━━━━━━━━━━━━━ 13:28 2s/step - pérdida: 0.1823Loss: 0.252134383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 241/613 ━━━━━━━━━━━━━━━━━━━━ 13:26 2s/step - pérdida: 0.1826Loss: 0.247575939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 242/613 ━━━━━━━━━━━━━━━━━━━━ 13:24 2s/step - pérdida: 0.1829Loss: 0.251734406
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 243/613 ━━━━━━━━━━━━━━━━━━━━ 13:22 2s/step - pérdida: 0.1832Loss: 0.247680247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 244/613 ━━━━━━━━━━━━━━━━━━━━ 13:20 2s/step - pérdida: 0.1834Loss: 0.241809666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 245/613 ━━━━━━━━━━━━━━━━━━━━ 13:18 2s/step - pérdida: 0.1837Loss: 0.244636521
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 246/613 ━━━━━━━━━━━━━━━━━━━━ 13:16 2s/step - pérdida: 0.1839Loss: 0.239890128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 247/613 ━━━━━━━━━━━━━━━━━━━━ 13:14 2s/step - pérdida: 0.1841Loss: 0.250479937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 248/613 ━━━━━━━━━━━━━━━━━━━━ 13:11 2s/step - pérdida: 0.1844Loss: 0.237161726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 249/613 ━━━━━━━━━━━━━━━━━━━━ 13:09 2s/step - pérdida: 0.1846Loss: 0.247501284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 250/613 ━━━━━━━━━━━━━━━━━━━━ 13:07 2s/step - pérdida: 0.1849Loss: 0.251149267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 251/613 ━━━━━━━━━━━━━━━━━━━━ 13:05 2s/step - pérdida: 0.1851Loss: 0.251576841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 252/613 ━━━━━━━━━━━━━━━━━━━━ 13:03 2s/step - pérdida: 0.1854Loss: 0.255177319
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 253/613 ━━━━━━━━━━━━━━━━━━━━ 13:01 2s/step - pérdida: 0.1857Loss: 0.247267127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 254/613 ━━━━━━━━━━━━━━━━━━━━ 12:58 2s/step - pérdida: 0.1859Loss: 0.248162687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 255/613 ━━━━━━━━━━━━━━━━━━━━ 12:56 2s/step - pérdida: 0.1862Loss: 0.241837397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 256/613 ━━━━━━━━━━━━━━━━━━━━ 12:54 2s/step - pérdida: 0.1864Loss: 0.243753731
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 257/613 ━━━━━━━━━━━━━━━━━━━━ 12:52 2s/step - pérdida: 0.1866Loss: 0.250062793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 258/613 ━━━━━━━━━━━━━━━━━━━━ 12:50 2s/step - pérdida: 0.1869Loss: 0.264437288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 259/613 ━━━━━━━━━━━━━━━━━━━━ 12:48 2s/step - pérdida: 0.1872Loss: 0.247107625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 260/613 ━━━━━━━━━━━━━━━━━━━━ 12:46 2s/step - pérdida: 0.1874Loss: 0.25718537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 261/613 ━━━━━━━━━━━━━━━━━━━━ 12:44 2s/step - pérdida: 0.1877Loss: 0.241250575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 262/613 ━━━━━━━━━━━━━━━━━━━━ 12:41 2s/step - pérdida: 0.1879Loss: 0.248030901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 263/613 ━━━━━━━━━━━━━━━━━━━━ 12:39 2s/step - pérdida: 0.1881Loss: 0.259129018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 264/613 ━━━━━━━━━━━━━━━━━━━━ 12:37 2s/step - pérdida: 0.1884Loss: 0.248342574
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 265/613 ━━━━━━━━━━━━━━━━━━━━ 12:35 2s/step - pérdida: 0.1886Loss: 0.253192782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 266/613 ━━━━━━━━━━━━━━━━━━━━ 12:33 2s/step - pérdida: 0.1888Loss: 0.249802724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 267/613 ━━━━━━━━━━━━━━━━━━━━ 12:31 2s/step - pérdida: 0.1891Loss: 0.252942264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 268/613 ━━━━━━━━━━━━━━━━━━━━ 12:28 2s/step - pérdida: 0.1893Loss: 0.253166258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 269/613 ━━━━━━━━━━━━━━━━━━━━ 12:26 2s/step - pérdida: 0.1895Loss: 0.249939397
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 270/613 ━━━━━━━━━━━━━━━━━━━━ 12:24 2s/step - pérdida: 0.1898Loss: 0.257463217
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 271/613 ━━━━━━━━━━━━━━━━━━━━ 12:22 2s/step - pérdida: 0.1900Loss: 0.249843687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 272/613 ━━━━━━━━━━━━━━━━━━━━ 12:20 2s/step - pérdida: 0.1902Loss: 0.249126509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 273/613 ━━━━━━━━━━━━━━━━━━━━ 12:18 2s/step - pérdida: 0.1904Loss: 0.244942695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 274/613 ━━━━━━━━━━━━━━━━━━━━ 12:15 2s/step - pérdida: 0.1906Loss: 0.251075804
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 275/613 ━━━━━━━━━━━━━━━━━━━━ 12:13 2s/step - pérdida: 0.1909Loss: 0.247346848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 276/613 ━━━━━━━━━━━━━━━━━━━━ 12:11 2s/step - pérdida: 0.1911Loss: 0.249666139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 277/613 ━━━━━━━━━━━━━━━━━━━━ 12:09 2s/step - pérdida: 0.1913Loss: 0.251033813
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 278/613 ━━━━━━━━━━━━━━━━━━━━ 12:07 2s/step - pérdida: 0.1915Loss: 0.252438396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 279/613 ━━━━━━━━━━━━━━━━━━━━ 12:05 2s/step - pérdida: 0.1917Loss: 0.246970117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 280/613 ━━━━━━━━━━━━━━━━━━━━ 12:02 2s/step - pérdida: 0.1919Loss: 0.246629626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 281/613 ━━━━━━━━━━━━━━━━━━━━ 12:00 2s/step - pérdida: 0.1921Loss: 0.242219433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 282/613 ━━━━━━━━━━━━━━━━━━━━ 11:58 2s/step - pérdida: 0.1923Loss: 0.247229531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 283/613 ━━━━━━━━━━━━━━━━━━━━ 11:56 2s/step - pérdida: 0.1925Loss: 0.243275791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 284/613 ━━━━━━━━━━━━━━━━━━━━ 11:54 2s/step - pérdida: 0.1926Loss: 0.249672979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 285/613 ━━━━━━━━━━━━━━━━━━━━ 11:51 2s/step - pérdida: 0.1928Loss: 0.246471524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 286/613 ━━━━━━━━━━━━━━━━━━━━ 11:49 2s/step - pérdida: 0.1930Loss: 0.245977372
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 287/613 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - pérdida: 0.1932Loss: 0.242697835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 288/613 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - pérdida: 0.1934Loss: 0.256999016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 289/613 ━━━━━━━━━━━━━━━━━━━━ 11:43 2s/step - pérdida: 0.1936Loss: 0.252673954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 290/613 ━━━━━━━━━━━━━━━━━━━━ 11:41 2s/step - pérdida: 0.1938Loss: 0.24778825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 291/613 ━━━━━━━━━━━━━━━━━━━━ 11:38 2s/step - pérdida: 0.1940Loss: 0.247201294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 292/613 ━━━━━━━━━━━━━━━━━━━━ 11:36 2s/step - pérdida: 0.1942Loss: 0.248311907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 293/613 ━━━━━━━━━━━━━━━━━━━━ 11:34 2s/step - pérdida: 0.1944Loss: 0.250974298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 294/613 ━━━━━━━━━━━━━━━━━━━━ 11:32 2s/step - pérdida: 0.1946Loss: 0.247973591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 295/613 ━━━━━━━━━━━━━━━━━━━━ 11:30 2s/step - pérdida: 0.1947Loss: 0.252256542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 296/613 ━━━━━━━━━━━━━━━━━━━━ 11:27 2s/step - pérdida: 0.1949Loss: 0.258080602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 297/613 ━━━━━━━━━━━━━━━━━━━━ 11:25 2s/step - pérdida: 0.1951Loss: 0.24526462
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 298/613 ━━━━━━━━━━━━━━━━━━━━ 11:23 2s/step - pérdida: 0.1953Loss: 0.249878153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 299/613 ━━━━━━━━━━━━━━━━━━━━ 11:21 2s/step - pérdida: 0.1955Loss: 0.242609754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 300/613 ━━━━━━━━━━━━━━━━━━━━ 11:19 2s/step - pérdida: 0.1957Loss: 0.24511157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 301/613 ━━━━━━━━━━━━━━━━━━━━ 11:17 2s/step - pérdida: 0.1958Loss: 0.257087946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 302/613 ━━━━━━━━━━━━━━━━━━━━ 11:14 2s/step - pérdida: 0.1960Loss: 0.247898236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 303/613 ━━━━━━━━━━━━━━━━━━━━ 11:12 2s/step - pérdida: 0.1962Loss: 0.24150905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 304/613 ━━━━━━━━━━━━━━━━━━━━ 11:10 2s/step - pérdida: 0.1963Loss: 0.244909346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 305/613 ━━━━━━━━━━━━━━━━━━━━ 11:08 2s/step - pérdida: 0.1965Loss: 0.252972603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 306/613 ━━━━━━━━━━━━━━━━━━━━ 11:06 2s/step - pérdida: 0.1967Loss: 0.24752602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 307/613 ━━━━━━━━━━━━━━━━━━━━ 11:04 2s/step - pérdida: 0.1969Loss: 0.255320191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 308/613 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - pérdida: 0.1970Loss: 0.250280857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 309/613 ━━━━━━━━━━━━━━━━━━━━ 10:59 2s/step - pérdida: 0.1972Loss: 0.260511637
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 310/613 ━━━━━━━━━━━━━━━━━━━━ 10:57 2s/step - pérdida: 0.1974Loss: 0.258028924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 311/613 ━━━━━━━━━━━━━━━━━━━━ 10:55 2s/step - pérdida: 0.1976Loss: 0.252430975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 312/613 ━━━━━━━━━━━━━━━━━━━━ 10:53 2s/step - pérdida: 0.1978Loss: 0.250162512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 313/613 ━━━━━━━━━━━━━━━━━━━━ 10:51 2s/step - pérdida: 0.1980Loss: 0.258162022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 314/613 ━━━━━━━━━━━━━━━━━━━━ 10:48 2s/step - pérdida: 0.1982Loss: 0.250553697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 315/613 ━━━━━━━━━━━━━━━━━━━━ 10:46 2s/step - pérdida: 0.1983Loss: 0.254875362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 316/613 ━━━━━━━━━━━━━━━━━━━━ 10:44 2s/step - pérdida: 0.1985Loss: 0.250159204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 317/613 ━━━━━━━━━━━━━━━━━━━━ 10:42 2s/step - pérdida: 0.1987Loss: 0.257353902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 318/613 ━━━━━━━━━━━━━━━━━━━━ 10:40 2s/step - pérdida: 0.1988Loss: 0.246976286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 319/613 ━━━━━━━━━━━━━━━━━━━━ 10:38 2s/step - pérdida: 0.1990Loss: 0.251772135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 320/613 ━━━━━━━━━━━━━━━━━━━━ 10:35 2s/step - pérdida: 0.1992Loss: 0.248060673
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 321/613 ━━━━━━━━━━━━━━━━━━━━ 10:33 2s/step - pérdida: 0.1993Loss: 0.249128729
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 322/613 ━━━━━━━━━━━━━━━━━━━━ 10:31 2s/step - pérdida: 0.1995Loss: 0.253039747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 323/613 ━━━━━━━━━━━━━━━━━━━━ 10:29 2s/step - pérdida: 0.1996Loss: 0.250786543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 324/613 ━━━━━━━━━━━━━━━━━━━━ 10:27 2s/step - pérdida: 0.1998Loss: 0.248992205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 325/613 ━━━━━━━━━━━━━━━━━━━━ 10:25 2s/step - pérdida: 0.1999Loss: 0.255042106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 326/613 ━━━━━━━━━━━━━━━━━━━━ 10:22 2s/step - pérdida: 0.2001Loss: 0.250734627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 327/613 ━━━━━━━━━━━━━━━━━━━━ 10:20 2s/step - pérdida: 0.2003Loss: 0.253409326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 328/613 ━━━━━━━━━━━━━━━━━━━━ 10:18 2s/step - pérdida: 0.2004Loss: 0.245055914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 329/613 ━━━━━━━━━━━━━━━━━━━━ 10:16 2s/step - pérdida: 0.2006Loss: 0.24890092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 330/613 ━━━━━━━━━━━━━━━━━━━━ 10:14 2s/step - pérdida: 0.2007Loss: 0.255649626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 331/613 ━━━━━━━━━━━━━━━━━━━━ 10:12 2s/step - pérdida: 0.2009Loss: 0.249717459
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 332/613 ━━━━━━━━━━━━━━━━━━━━ 10:09 2s/step - pérdida: 0.2010Loss: 0.249363765
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 333/613 ━━━━━━━━━━━━━━━━━━━━ 10:07 2s/step - pérdida: 0.2012Loss: 0.248733848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 334/613 ━━━━━━━━━━━━━━━━━━━━ 10:05 2s/step - pérdida: 0.2013Loss: 0.251279116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 335/613 ━━━━━━━━━━━━━━━━━━━━ 10:03 2s/step - pérdida: 0.2015Loss: 0.245022386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 336/613 ━━━━━━━━━━━━━━━━━━━━ 10:01 2s/step - pérdida: 0.2016Loss: 0.252577364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 337/613 ━━━━━━━━━━━━━━━━━━━━ 9:59 2s/step - pérdida: 0.2017 Loss: 0.249539405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 338/613 ━━━━━━━━━━━━━━━━━━━━ 9:56 2s/step - pérdida: 0.2019Loss: 0.247497201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 339/613 ━━━━━━━━━━━━━━━━━━━━ 9:54 2s/step - pérdida: 0.2020Loss: 0.252744555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 340/613 ━━━━━━━━━━━━━━━━━━━━ 9:52 2s/step - pérdida: 0.2022Loss: 0.242186099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 341/613 ━━━━━━━━━━━━━━━━━━━━ 9:50 2s/step - pérdida: 0.2023Loss: 0.254633725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 342/613 ━━━━━━━━━━━━━━━━━━━━ 9:48 2s/step - pérdida: 0.2024Loss: 0.247285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 343/613 ━━━━━━━━━━━━━━━━━━━━ 9:46 2s/step - pérdida: 0.2026Loss: 0.256436259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 344/613 ━━━━━━━━━━━━━━━━━━━━ 9:43 2s/step - pérdida: 0.2027Loss: 0.250782669
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 345/613 ━━━━━━━━━━━━━━━━━━━━ 9:41 2s/step - pérdida: 0.2029Loss: 0.248405725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 346/613 ━━━━━━━━━━━━━━━━━━━━ 9:39 2s/step - pérdida: 0.2030Loss: 0.25050354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 347/613 ━━━━━━━━━━━━━━━━━━━━ 9:37 2s/step - pérdida: 0.2031Loss: 0.249434799
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 348/613 ━━━━━━━━━━━━━━━━━━━━ 9:35 2s/step - pérdida: 0.2033Loss: 0.246894717
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 349/613 ━━━━━━━━━━━━━━━━━━━━ 9:33 2s/step - pérdida: 0.2034Loss: 0.249747247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 350/613 ━━━━━━━━━━━━━━━━━━━━ 9:31 2s/step - pérdida: 0.2035Loss: 0.248332858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 351/613 ━━━━━━━━━━━━━━━━━━━━ 9:29 2s/step - pérdida: 0.2036Loss: 0.249610618
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 352/613 ━━━━━━━━━━━━━━━━━━━━ 9:27 2s/step - pérdida: 0.2038Loss: 0.248919815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 353/613 ━━━━━━━━━━━━━━━━━━━━ 9:25 2s/step - pérdida: 0.2039Loss: 0.246934533
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 354/613 ━━━━━━━━━━━━━━━━━━━━ 9:22 2s/step - pérdida: 0.2040Loss: 0.252661288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 355/613 ━━━━━━━━━━━━━━━━━━━━ 9:20 2s/step - pérdida: 0.2042Loss: 0.246914744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 356/613 ━━━━━━━━━━━━━━━━━━━━ 9:18 2s/step - pérdida: 0.2043Loss: 0.243355662
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 357/613 ━━━━━━━━━━━━━━━━━━━━ 9:16 2s/step - pérdida: 0.2044Loss: 0.244998485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 358/613 ━━━━━━━━━━━━━━━━━━━━ 9:14 2s/step - pérdida: 0.2045Loss: 0.252348691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 359/613 ━━━━━━━━━━━━━━━━━━━━ 9:11 2s/step - pérdida: 0.2046Loss: 0.239669219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 360/613 ━━━━━━━━━━━━━━━━━━━━ 9:09 2s/step - pérdida: 0.2047Loss: 0.235624969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 361/613 ━━━━━━━━━━━━━━━━━━━━ 9:07 2s/step - pérdida: 0.2048Loss: 0.240689576
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 362/613 ━━━━━━━━━━━━━━━━━━━━ 9:04 2s/step - pérdida: 0.2049Loss: 0.256860316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 363/613 ━━━━━━━━━━━━━━━━━━━━ 9:02 2s/step - pérdida: 0.2051Loss: 0.230125949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 364/613 ━━━━━━━━━━━━━━━━━━━━ 9:00 2s/step - pérdida: 0.2051Loss: 0.245447978
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 365/613 ━━━━━━━━━━━━━━━━━━━━ 8:58 2s/step - pérdida: 0.2052Loss: 0.246104583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 366/613 ━━━━━━━━━━━━━━━━━━━━ 8:55 2s/step - pérdida: 0.2054Loss: 0.268120706
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 367/613 ━━━━━━━━━━━━━━━━━━━━ 8:53 2s/step - pérdida: 0.2055Loss: 0.244973779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 368/613 ━━━━━━━━━━━━━━━━━━━━ 8:51 2s/step - pérdida: 0.2056Loss: 0.235133469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 369/613 ━━━━━━━━━━━━━━━━━━━━ 8:48 2s/step - pérdida: 0.2057Loss: 0.243482023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 370/613 ━━━━━━━━━━━━━━━━━━━━ 8:46 2s/step - pérdida: 0.2058Loss: 0.240242943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 371/613 ━━━━━━━━━━━━━━━━━━━━ 8:44 2s/step - pérdida: 0.2059Loss: 0.247924417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 372/613 ━━━━━━━━━━━━━━━━━━━━ 8:42 2s/step - pérdida: 0.2060Loss: 0.227816895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 373/613 ━━━━━━━━━━━━━━━━━━━━ 8:39 2s/step - pérdida: 0.2061Loss: 0.238611624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 374/613 ━━━━━━━━━━━━━━━━━━━━ 8:37 2s/step - pérdida: 0.2062Loss: 0.229958862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 375/613 ━━━━━━━━━━━━━━━━━━━━ 8:35 2s/step - pérdida: 0.2062Loss: 0.24978143

# %%
# Inicializar métricas de Recuperación y Precisión para la evaluación sobre los datos de prueba
recall_metric = Recall()
precision_metric = Precision()

for sample_image, validate_image, true_label in test_data.as_numpy_iterator():
    # Obtener las predicciones del modelo siamesa
    predict_label = siamese_model.predict([sample_image,validate_image])
    # Actualizar la métrica de Recuperación con las etiquetas verdaderas y las predicciones
    recall_metric.update_state(true_label, predict_label)
    # Actualizar la métrica de Precisión con las etiquetas verdaderas y las predicciones
    precision_metric.update_state(true_label, predict_label)


# Print final recall and precision results
print(f'Recall: {recall_metric.result().numpy()}, Precision: {precision_metric.result().numpy()}')

# %%
def load_siamese_model(save_model_dir, date_str=None):
    custom_objects = {
        'L1Dist': L1Dist, 
        'Contrastive_loss': contrastive_loss  
    }

    if date_str:
        # Si se proporciona una fecha, intenta cargar el modelo correspondiente
        model_filename = f"siamese_model_{date_str}.h5"
        model_filepath = os.path.join(save_model_dir, model_filename)
        if os.path.exists(model_filepath):
            print(f"Cargando el modelo desde: {model_filepath}")
            return tf.keras.models.load_model(model_filepath, custom_objects=custom_objects)
        else:
            raise FileNotFoundError(f"No se encontró el modelo para la fecha proporcionada: {date_str}")
    else:
        # Si no se proporciona una fecha, carga el modelo más reciente
        model_files = [f for f in os.listdir(save_model_dir) if f.startswith("siamese_model_") and f.endswith(".h5")]
        if not model_files:
            raise FileNotFoundError("No se encontraron modelos en el directorio especificado.")
        
        # Ordenar los archivos por fecha y hora en el nombre del archivo
        model_files.sort(key=lambda x: datetime.datetime.strptime(x.split("_", 2)[2].split(".")[0], "%Y_%m_%d_%H_%M"), reverse=True)
        latest_model_filename = model_files[0]
        latest_model_filepath = os.path.join(save_model_dir, latest_model_filename)
        print(f"Cargando el modelo más reciente desde: {latest_model_filepath}")
        return tf.keras.models.load_model(latest_model_filepath, custom_objects=custom_objects)

# %%
model_date = '2024_08_08_17_19'
model_filename = f"siamese_model_{model_date}.h5"
# Guardar el modelo en el subdirectorio

if save_flag:
    siamese_model.save(os.path.join(save_model_dir,model_filename))

# %%
# Para cargar un modelo específico por fecha
# model = load_siamese_model(save_model_path, "2024_08_01_12_00")

# Para cargar el modelo más reciente
try:
    siamese_model = load_siamese_model(save_model_dir)
except Exception as e:
    print(f'Error loading model: {e}')

# %%
# View model summary
siamese_model.summary()

# %%
# 70/ 70
def verify(model, input_image, verific_dir, detection_threshold, verification_threshold):
    results = []
    
    # Preprocesar la imagen de entrada para que tenga el formato adecuado para el modelo
    input_img = preprocess_image(input_image)
    
    # Iterar sobre cada imagen en el directorio de verificación
    for image in verific_dir:
        validation_img = preprocess_image(os.path.join(verific_dir, image))
        
        result = model.predict(list(np.expand_dims([input_img, validation_img], axis=1)))
        
        results.append(result)
    
    # Threshold de detección: contar cuántas predicciones son mayores que el umbral de detección
    detection = np.sum(np.array(results) > detection_threshold)
    
    # Threshold de verificación: calcular la proporción de predicciones positivas sobre el total de muestras positivas
    verification = detection / len(os.listdir(os.path.join(verific_dir))) 
    
    # Verificar si la proporción de predicciones positivas es mayor que el umbral de verificación
    verified = verification > verification_threshold
    
    # Devolver los resultados de las predicciones y el resultado de la verificación
    return results, verified

# %%
import os

def detect_and_verify_face(siamese_model, db_dir, detection_threshold=0.7, verification_threshold=0.7):
    count, input_images = collect_images()  # Assuming this function is already defined

    # Check if any image was captured
    if count > 0:
        input_image = input_images[0]  # Take the first captured image
        person_found = False  # Flag to check if a match is found
        person_results = []
        # Iterate over each person in the database directory
        for person_folder in os.listdir(db_dir):
            person_dir = os.path.join(db_dir, person_folder)

            # Ensure it's a directory
            if not os.path.isdir(person_dir):
                continue

            results, person_verified = verify(siamese_model, input_image, person_dir, detection_threshold, verification_threshold)
            person_results.append((results, person_verified))
                
        return max(person_results, key=lambda x: x[0])
    else:
        print("No image was captured.")
        return None

# %%
detect_and_verify_face(siamese_model,db_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 detect_and_verify_face(siamese_model,db_dir)
#
# NameError: name 'detect_and_verify_face' is not defined
